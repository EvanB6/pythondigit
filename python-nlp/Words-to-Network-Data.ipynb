# %% [markdown]
# ## Words to Network Data
#
# Now that we know some ways to pull an interesting selection of words, let's think about them like a network. Network analysis involves looking at how things relate to each other based on shared properties.
#
# In this notebook, we will address a simple research question: Which **files** (or **chapters**, or **scenes**, or **authors**, or **titles**) share each others' top 5 or 10 **verbs** (or **adjectives**, or **nouns**, or **WordNet synsets**, etc)?
#
# We will try exploring this as a network of data and import it into network visualization software.
#
# ### Installs in your Terminal
# * If you did not do this in the previous notebook: `pip install spacy`
# * We need the **pandas** library to make dataframes: `pip install pandas`
#
# <pre>
#     ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⣶⣿⣷⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣦⡀
# ⠀⠀⠀⠀⢀⠄⠀⠀⠀⠀⢈⣿⣿⣿⠟⠛⠁⠀⠀⠀⠀⠀⠀⠐⢿⣿⣿⣿⣿⣷
# ⠀⠀⢀⡔⠁⠀⠀⠀⢀⣴⡿⠃⠈⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣿⠟⠁
# ⠀⣠⡟⠀⠀⠀⠀⣰⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢠⣿⠁⠀⠀⠀⢰⣿⣿⡏⠀⠀⠀⢀⣤⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⣾⣿⠀⠀⠀⠀⢸⣿⣿⡇⠀⠀⢠⣿⣿⣿⣿⠀⠀⠀⠀⣰⣾⣶⣆⠀⠀⠀⠀⡄
# ⣿⣿⡀⠀⠀⠀⢸⣿⣿⣧⠀⠀⢸⣿⣿⡿⠃⠀⠀⠀⠀⢿⣿⣿⣿⡆⠀⠀⢸⣧
# ⢿⣿⣧⠀⠀⠀⢸⣿⣿⣿⣦⡀⠀⠉⠉⠀⠀⠀⠀⠀⠀⠈⠻⣿⠿⠁⠀⢠⣿⣿
# ⢸⣿⣿⣷⣄⠀⣿⣿⣿⣿⣿⣿⣷⣦⣄⠀⠲⣶⣶⣶⠀⠀⠀⠀⠀⣀⣴⣿⣿⣿
# ⢰⣿⣿⣿⣿⣷⣽⣿⣿⣿⣿⣿⣿⣿⣿⣦⡄⣬⣅⣀⣠⣾⣿⣿⣿⣿⣿⣿⣿⡟
# ⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣤⣤⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⠇
# ⠀⠹⣿⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⠈⣿⣿⣿⣿⣿⣿⣿⡿⠀
# ⠀⠀⠻⣿⣿⣿⣿⣿⡎⢿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⣿⣿⣿⣿⣿⣿⣿⠃⠀
# ⠀⠀⠀⠙⠻⠿⣿⣿⠗⠀⢻⣿⣿⣿⣿⣿⣿⣿⡇⠀⢸⣿⣿⣿⣿⣿⡿⠃⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣿⣿⣿⣿⣿⣿⣿⠀⢸⣿⣿⣿⡿⠟⠁⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⠿⢿⣿⣿⡿⠇⠀⠈⠉⠁⠀⠀⠀⠀⠀⠀
# </pre>
#
#
#
# Image credit: <https://emojicombos.com/panda-ascii-art>
#
# ### Language Models
# Like NLTK's collections that we downloaded, [spaCy has trained language models](https://spacy.io/usage/models) to download. You download these in your Python script after you import spacy, and after you download once, you don't need to do it again (so you can comment out the download line). We're going to try the medium and large models in English. (It's good to know that both spaCy and NLTK have resources for NLP on other languages, too!)

# %%
import spacy
import os

# %% [markdown]
# ### Downloading language models
# To work with spaCy's pre-trained language models, you need to download them to you virtual environment. There are:
# * en_core_web_sm (smallest--not as much info as the others)
# * **en_core_web_md** (Pretty good date here, size: 34 MB )
# * **en_core_web_lg** (Lots of data here, size: 400 MB.)
# Note that the LARGEST  one will have the most data and probably be the most reliable.

# %%
# CAN YOU SKIP THIS???
# After you download a model into your virtual environment for the first time, you can comment out the download line.
# spaCy's medium and large models will give us the best results for NLP tagging.
# nlp = spacy.cli.download("en_core_web_sm")
# nlp = spacy.cli.download("en_core_web_md")
nlp = spacy.cli.download("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# ### Load the model
# Now we redefine the nlp variable to LOAD the model you downloaded.

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## File Collection
# You can set this to read a collection of text files that you've prepped for natural language processing.
# For this notebook, we'll work with just the dialogue text we pulled from the One Piece project.
# The text is organized as one file for each volume of OnePiece, so we can maybe explore how much the dialogue is relying on certain words, and how it might be changing over the volumes.
#
# We're going to get volume information from OnePiece's filenames (which look like this: `vol-9.txt'. We can use the `os` library to help us isolate the filename from the file extension. Let's try that so we can simplify our references to the volumes when we output our data.

# %%
collPath = '.\spytext'
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            lengthFile = len(readFile)
            print(lengthFile)
# We're just printing out the filepaths and lengths of the files as a "smoke test" to see if we're reading the files.
# Out:
# 02x01_-_Follow_Mama_and_Papa
# 12558
# 02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip
# 11470
# 02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child
# 10821
# 02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II
# 13800
# 02x05_-_Plan_to_Cross_the_Border
# 14583
# 02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 14389
# 02x07_-_Who_Is_This_Mission_For_
# 13177
# 02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 10944
# 02x09_-_The_Hand_That_Connects_to_the_Future
# 12074
# 02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation
# 10607
# 02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 13780
# 02x12_-_Part_of_the_Family
# 10227
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\coope\AppData\Local\Temp\ipykernel_21548\3678445407.py:1: SyntaxWarning: invalid escape sequence '\s'
#   collPath = '.\spytext'

# %% [markdown]
# ## Collect some words with a little help from spaCy
# Let's build this up to go file by file. We'll start by surveying what we have...(Ultimately we want to collect the top 5 or 10 most frequently repeating words of a kind.)

# %%
# SURVEY IT ALL! :-) (Yeah, lots of data...)
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            for token in spacyRead:
                print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# 02x01_-_Follow_Mama_and_Papa
# As ----> SCONJ ::::: as
# countries ----> NOUN ::::: country
# worldwide ----> ADJ ::::: worldwide
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# battle ----> NOUN ::::: battle
# discrete ----> ADJ ::::: discrete
# yet ----> CCONJ ::::: yet
# fierce ----> ADJ ::::: fierce
#
#
#  ----> SPACE :::::
#
#
# information ----> NOUN ::::: information
# warfare ----> NOUN ::::: warfare
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# two ----> NUM ::::: two
# countries ----> NOUN ::::: country
# are ----> AUX ::::: be
# at ----> ADP ::::: at
# a ----> DET ::::: a
# standoff ----> NOUN ::::: standoff
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Ostania ----> PROPN ::::: Ostania
# in ----> ADP ::::: in
# the ----> DET ::::: the
# east ----> NOUN ::::: east
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# and ----> CCONJ ::::: and
# Westalis ----> PROPN ::::: Westalis
# in ----> ADP ::::: in
# the ----> DET ::::: the
# west ----> NOUN ::::: west
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Westalis ----> PROPN ::::: Westalis
# launched ----> VERB ::::: launch
# Operation ----> PROPN ::::: Operation
# Strix ----> PROPN ::::: Strix
#
#
#  ----> SPACE :::::
#
#
# to ----> PART ::::: to
# find ----> VERB ::::: find
# out ----> ADP ::::: out
# the ----> DET ::::: the
# movements ----> NOUN ::::: movement
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# of ----> ADP ::::: of
# key ----> ADJ ::::: key
# figures ----> NOUN ::::: figure
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# in ----> ADP ::::: in
# the ----> DET ::::: the
# Ostanian ----> ADJ ::::: ostanian
# government ----> NOUN ::::: government
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# who ----> PRON ::::: who
# are ----> AUX ::::: be
# plotting ----> VERB ::::: plot
# a ----> DET ::::: a
# w*r ----> PROPN ::::: w*r
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Highly ----> ADV ::::: highly
# - ----> PUNCT ::::: -
# skilled ----> ADJ ::::: skilled
# Agent ----> NOUN ::::: agent
# Twilight ----> PROPN ::::: Twilight
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# was ----> AUX ::::: be
# put ----> VERB ::::: put
# in ----> ADP ::::: in
# charge ----> NOUN ::::: charge
# of ----> ADP ::::: of
# the ----> DET ::::: the
# operation ----> NOUN ::::: operation
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# The ----> DET ::::: the
# man ----> NOUN ::::: man
# with ----> ADP ::::: with
# 100 ----> NUM ::::: 100
# different ----> ADJ ::::: different
# faces ----> NOUN ::::: face
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# was ----> AUX ::::: be
# given ----> VERB ::::: give
# a ----> DET ::::: a
# mission ----> NOUN ::::: mission
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# to ----> PART ::::: to
# create ----> VERB ::::: create
# a ----> DET ::::: a
# family ----> NOUN ::::: family
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Father ----> PROPN ::::: Father
# , ----> PUNCT ::::: ,
# Loid ----> PROPN ::::: Loid
# Forger ----> PROPN ::::: Forger
# , ----> PUNCT ::::: ,
# a ----> DET ::::: a
# psychiatrist ----> NOUN ::::: psychiatrist
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# His ----> PRON ::::: his
# true ----> ADJ ::::: true
# identity ----> NOUN ::::: identity
# is ----> AUX ::::: be
# spy ----> NOUN ::::: spy
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Codenamed ----> VERB ::::: codename
# Twilight ----> PROPN ::::: Twilight
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Mother ----> PROPN ::::: Mother
# , ----> PUNCT ::::: ,
# Yor ----> PROPN ::::: Yor
# Forger ----> PROPN ::::: Forger
# , ----> PUNCT ::::: ,
# a ----> DET ::::: a
# city ----> NOUN ::::: city
# hall ----> NOUN ::::: hall
# employee ----> NOUN ::::: employee
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Her ----> PRON ::::: her
# true ----> ADJ ::::: true
# identity ----> NOUN ::::: identity
# is ----> AUX ::::: be
# assassin ----> NOUN ::::: assassin
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Codenamed ----> VERB ::::: codename
# Thorn ----> PROPN ::::: Thorn
# Princess ----> PROPN ::::: Princess
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Daughter ----> PROPN ::::: Daughter
# , ----> PUNCT ::::: ,
# Anya ----> PROPN ::::: Anya
# Forger ----> PROPN ::::: Forger
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Her ----> PRON ::::: her
# true ----> ADJ ::::: true
# identity ----> NOUN ::::: identity
# is ----> AUX ::::: be
# being ----> AUX ::::: be
# a ----> DET ::::: a
# telepath ----> NOUN ::::: telepath
#
#
#  ----> SPACE :::::
#
#
# who ----> PRON ::::: who
# can ----> AUX ::::: can
# read ----> VERB ::::: read
# minds ----> NOUN ::::: mind
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Dog ----> PROPN ::::: Dog
# , ----> PUNCT ::::: ,
# Bond ----> PROPN ::::: Bond
# Forger ----> PROPN ::::: Forger
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# A ----> DET ::::: a
# psychic ----> ADJ ::::: psychic
# canine ----> NOUN ::::: canine
#
#
#  ----> SPACE :::::
#
#
# that ----> PRON ::::: that
# can ----> AUX ::::: can
# glimpse ----> VERB ::::: glimpse
# the ----> DET ::::: the
# future ----> NOUN ::::: future
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# For ----> ADP ::::: for
# their ----> PRON ::::: their
# own ----> ADJ ::::: own
# personal ----> ADJ ::::: personal
# interests ----> NOUN ::::: interest
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# they ----> PRON ::::: they
# created ----> VERB ::::: create
# a ----> DET ::::: a
# fake ----> ADJ ::::: fake
# family ----> NOUN ::::: family
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# The ----> DET ::::: the
# mission ----> NOUN ::::: mission
# continues ----> VERB ::::: continue
# , ----> PUNCT ::::: ,
# as ----> SCONJ ::::: as
# three ----> NUM ::::: three
# of ----> ADP ::::: of
# them ----> PRON ::::: they
#
#
#  ----> SPACE :::::
#
#
# hide ----> VERB ::::: hide
# their ----> PRON ::::: their
# identities ----> NOUN ::::: identity
# from ----> ADP ::::: from
# each ----> DET ::::: each
# other ----> ADJ ::::: other
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# ORIGINAL ----> ADJ ::::: original
# WORK ----> NOUN ::::: work
# BY ----> ADP ::::: by
# TATSUYA ----> PROPN ::::: TATSUYA
# ENDO ----> PROPN ::::: ENDO
#
#
#  ----> SPACE :::::
#
#
# SERIALIZED ----> VERB ::::: serialize
# ON ----> ADP ::::: on
# SHUEISHA ----> PROPN ::::: SHUEISHA
# 'S ----> PART ::::: 's
# SHONEN ----> PROPN ::::: SHONEN
# JUMP ----> PROPN ::::: JUMP
# PLUS ----> ADP ::::: plus
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Yes ----> INTJ ::::: yes
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# The ----> DET ::::: the
# service ----> NOUN ::::: service
# has ----> AUX ::::: have
# been ----> AUX ::::: be
# completed ----> VERB ::::: complete
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# will ----> AUX ::::: will
# head ----> VERB ::::: head
# home ----> ADV ::::: home
# right ----> ADV ::::: right
# away ----> ADV ::::: away
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Since ----> SCONJ ::::: since
# my ----> PRON ::::: my
# husband ----> NOUN ::::: husband
# asked ----> VERB ::::: ask
# me ----> PRON ::::: I
# to ----> PART ::::: to
# pick ----> VERB ::::: pick
# up ----> ADP ::::: up
# some ----> DET ::::: some
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# milk ----> NOUN ::::: milk
# and ----> CCONJ ::::: and
# eggs ----> NOUN ::::: egg
# on ----> ADP ::::: on
# the ----> DET ::::: the
# way ----> NOUN ::::: way
# back ----> ADV ::::: back
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Damn ----> INTJ ::::: damn
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# 's ----> AUX ::::: be
# the ----> DET ::::: the
# infamous ----> ADJ ::::: infamous
# assassin ----> NOUN ::::: assassin
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# - ----> PUNCT ::::: -
# She ----> PRON ::::: she
# 's ----> PART ::::: 's
# Thorn ----> PROPN ::::: Thorn
# Princess ----> PROPN ::::: Princess
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# thank ----> VERB ::::: thank
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Die ----> VERB ::::: die
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# monster ----> NOUN ::::: monster
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# MISSION:26 ----> PROPN ::::: MISSION:26
#
#
#  ----> SPACE :::::
#
#
# FOLLOW ----> VERB ::::: follow
# MAMA ----> PROPN ::::: MAMA
# AND ----> CCONJ ::::: and
# PAPA ----> PROPN ::::: PAPA
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# We ----> PRON ::::: we
# have ----> AUX ::::: have
# breaking ----> VERB ::::: break
# news ----> NOUN ::::: news
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Several ----> ADJ ::::: several
# bodies ----> NOUN ::::: body
# believed ----> VERB ::::: believe
# to ----> PART ::::: to
# belong ----> VERB ::::: belong
# to ----> ADP ::::: to
#
#
#  ----> SPACE :::::
#
#
# members ----> NOUN ::::: member
# of ----> ADP ::::: of
# Red ----> PROPN ::::: Red
# Circus ----> PROPN ::::: Circus
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# were ----> AUX ::::: be
# found ----> VERB ::::: find
# inside ----> ADP ::::: inside
# a ----> DET ::::: a
# building ----> NOUN ::::: building
#
#
#  ----> SPACE :::::
#
#
# in ----> ADP ::::: in
# the ----> DET ::::: the
# Northern ----> PROPN ::::: Northern
# District ----> PROPN ::::: District
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# - ----> PUNCT ::::: -
# Red ----> PROPN ::::: Red
# Circus ----> PROPN ::::: Circus
# is ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Father ----> PROPN ::::: Father
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# want ----> VERB ::::: want
# to ----> PART ::::: to
# watch ----> VERB ::::: watch
# anime ----> NOUN ::::: anime
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# News ----> PROPN ::::: News
# is ----> AUX ::::: be
# boring ----> ADJ ::::: boring
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# No ----> NOUN ::::: no
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# a ----> DET ::::: a
# load ----> NOUN ::::: load
# of ----> ADP ::::: of
# information ----> NOUN ::::: information
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# to ----> PART ::::: to
# gain ----> VERB ::::: gain
# from ----> ADP ::::: from
# a ----> DET ::::: a
# single ----> ADJ ::::: single
# news ----> NOUN ::::: news
# bulletin ----> NOUN ::::: bulletin
#
#
#  ----> SPACE :::::
#
#
# released ----> VERB ::::: release
# to ----> ADP ::::: to
# the ----> DET ::::: the
# public ----> NOUN ::::: public
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Fine ----> PROPN ::::: Fine
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# can ----> AUX ::::: can
# change ----> VERB ::::: change
# the ----> DET ::::: the
# channel ----> NOUN ::::: channel
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Good ----> ADJ ::::: good
# morning ----> NOUN ::::: morning
# , ----> PUNCT ::::: ,
# Bondman ----> PROPN ::::: Bondman
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Your ----> PRON ::::: your
# mission ----> NOUN ::::: mission
# today ----> NOUN ::::: today
#
#
#  ----> SPACE :::::
#
#
# is ----> AUX ::::: be
# to ----> PART ::::: to
# tail ----> VERB ::::: tail
# a ----> DET ::::: a
# certain ----> ADJ ::::: certain
# target ----> NOUN ::::: target
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# - ----> PUNCT ::::: -
# Find ----> VERB ::::: find
# out ----> ADP ::::: out
# where ----> SCONJ ::::: where
# ... ----> PUNCT ::::: ...
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# How ----> SCONJ ::::: how
# exciting ----> ADJ ::::: exciting
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# the ----> DET ::::: the
# secret ----> ADJ ::::: secret
# weapons ----> NOUN ::::: weapon
# are ----> AUX ::::: be
# hidden ----> VERB ::::: hide
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# - ----> PUNCT ::::: -
# and ----> CCONJ ::::: and
# destroy ----> VERB ::::: destroy
# them ----> PRON ::::: they
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# home ----> NOUN ::::: home
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Welcome ----> PROPN ::::: Welcome
# home ----> NOUN ::::: home
# , ----> PUNCT ::::: ,
# Yor ----> PROPN ::::: Yor
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# These ----> PRON ::::: these
# are ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# the ----> DET ::::: the
# milk ----> NOUN ::::: milk
# and ----> CCONJ ::::: and
# eggs ----> NOUN ::::: egg
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Oh ----> INTJ ::::: oh
# ... ----> PUNCT ::::: ...
# Thank ----> VERB ::::: thank
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# feeling ----> VERB ::::: feel
# unwell ----> ADJ ::::: unwell
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# nothing ----> PRON ::::: nothing
# like ----> ADP ::::: like
# that ----> PRON ::::: that
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# just ----> ADV ::::: just
# a ----> DET ::::: a
# little ----> ADJ ::::: little
# ... ----> PUNCT ::::: ...
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# no ----> DET ::::: no
# way ----> NOUN ::::: way
# I ----> PRON ::::: I
# can ----> AUX ::::: can
# tell ----> VERB ::::: tell
# him ----> PRON ::::: he
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# tell ----> VERB ::::: tell
# him ----> PRON ::::: he
# that ----> SCONJ ::::: that
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# in ----> ADP ::::: in
# a ----> DET ::::: a
# lot ----> NOUN ::::: lot
# of ----> ADP ::::: of
# pain ----> NOUN ::::: pain
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# got ----> AUX ::::: get
# shot ----> VERB ::::: shoot
# in ----> ADP ::::: in
# the ----> DET ::::: the
# butt ----> NOUN ::::: butt
#
#
#  ----> SPACE :::::
#
#
# during ----> ADP ::::: during
# a ----> DET ::::: a
# fight ----> NOUN ::::: fight
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# with ----> ADP ::::: with
# a ----> DET ::::: a
# group ----> NOUN ::::: group
# of ----> ADP ::::: of
# armed ----> ADJ ::::: armed
# militants ----> NOUN ::::: militant
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# treated ----> VERB ::::: treat
# the ----> DET ::::: the
# wound ----> NOUN ::::: wound
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# still ----> ADV ::::: still
# ... ----> PUNCT ::::: ...
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# g*ns ----> NOUN ::::: g*ns
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
# She ----> PRON ::::: she
# got ----> AUX ::::: get
# shot ----> VERB ::::: shoot
# by ----> ADP ::::: by
# a ----> DET ::::: a
# g*n ----> PROPN ::::: g*n
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mother ----> PROPN ::::: Mother
# . ----> PUNCT ::::: .
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# going ----> VERB ::::: go
# to ----> PART ::::: to
# die ----> VERB ::::: die
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# worry ----> VERB ::::: worry
# , ----> PUNCT ::::: ,
# Anya ----> PROPN ::::: Anya
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# wo ----> AUX ::::: will
# n't ----> PART ::::: not
# die ----> VERB ::::: die
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# a ----> DET ::::: a
# little ----> ADJ ::::: little
# tired ----> ADJ ::::: tired
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# so ----> ADV ::::: so
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# head ----> VERB ::::: head
# to ----> ADP ::::: to
# bed ----> NOUN ::::: bed
# now ----> ADV ::::: now
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# sure ----> ADJ ::::: sure
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# feel ----> VERB ::::: feel
# better ----> ADJ ::::: well
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# after ----> ADP ::::: after
# a ----> DET ::::: a
# good ----> ADJ ::::: good
# night ----> NOUN ::::: night
# 's ----> PART ::::: 's
# sleep ----> NOUN ::::: sleep
# , ----> PUNCT ::::: ,
# right ----> ADJ ::::: right
# ? ----> PUNCT ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Yor ----> PROPN ::::: Yor
# was ----> AUX ::::: be
# in ----> ADP ::::: in
# a ----> DET ::::: a
# bad ----> ADJ ::::: bad
# mood ----> NOUN ::::: mood
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Was ----> AUX ::::: be
# it ----> PRON ::::: it
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# asked ----> VERB ::::: ask
# her ----> PRON ::::: she
# to ----> PART ::::: to
# go ----> VERB ::::: go
# shopping ----> VERB ::::: shop
# ? ----> PUNCT ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# That ----> PRON ::::: that
# must ----> AUX ::::: must
# be ----> AUX ::::: be
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# This ----> DET ::::: this
# marriage ----> NOUN ::::: marriage
# is ----> AUX ::::: be
# just ----> ADV ::::: just
# on ----> ADP ::::: on
# paper ----> NOUN ::::: paper
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# but ----> CCONJ ::::: but
# I ----> PRON ::::: I
# 've ----> AUX ::::: have
# been ----> AUX ::::: be
# asking ----> VERB ::::: ask
# her ----> PRON ::::: she
# to ----> PART ::::: to
# do ----> VERB ::::: do
# so ----> ADV ::::: so
# much ----> ADV ::::: much
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# That ----> PRON ::::: that
# must ----> AUX ::::: must
# 've ----> AUX ::::: 've
# made ----> VERB ::::: make
# her ----> PRON ::::: she
# unhappy ----> ADJ ::::: unhappy
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Mother ----> PROPN ::::: Mother
# wo ----> AUX ::::: will
# n't ----> PART ::::: not
# die ----> VERB ::::: die
# even ----> ADV ::::: even
# when ----> SCONJ ::::: when
# she ----> PRON ::::: she
# gets ----> AUX ::::: get
#
#
#  ----> SPACE :::::
#
#
# shot ----> VERB ::::: shoot
# by ----> ADP ::::: by
# a ----> DET ::::: a
# g*n ----> NOUN ::::: g*n
# ! ----> PUNCT ::::: !
# Impressive ----> ADJ ::::: impressive
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# not ----> PART ::::: not
# good ----> ADJ ::::: good
# ! ----> PUNCT ::::: !
# Not ----> PART ::::: not
# good ----> ADJ ::::: good
# at ----> ADV ::::: at
# all ----> ADV ::::: all
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Family ----> PROPN ::::: Family
# troubles ----> NOUN ::::: trouble
# will ----> AUX ::::: will
# ruin ----> VERB ::::: ruin
# this ----> DET ::::: this
# mission ----> NOUN ::::: mission
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# must ----> AUX ::::: must
# do ----> VERB ::::: do
# everything ----> PRON ::::: everything
# within ----> ADP ::::: within
# my ----> PRON ::::: my
# power ----> NOUN ::::: power
#
#
#  ----> SPACE :::::
#
#
# to ----> PART ::::: to
# fix ----> VERB ::::: fix
# this ----> PRON ::::: this
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Father ----> PROPN ::::: Father
# 's ----> PART ::::: 's
# way ----> NOUN ::::: way
# off ----> ADV ::::: off
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Hopefully ----> ADV ::::: hopefully
# she ----> PRON ::::: she
# 'll ----> AUX ::::: will
# feel ----> VERB ::::: feel
# better ----> ADJ ::::: well
#
#
#  ----> SPACE :::::
#
#
# after ----> ADP ::::: after
# a ----> DET ::::: a
# night ----> NOUN ::::: night
# 's ----> PART ::::: 's
# sleep ----> NOUN ::::: sleep
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# - ----> PUNCT ::::: -
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# better ----> ADJ ::::: well
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# She ----> PRON ::::: she
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# better ----> ADJ ::::: well
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Good ----> ADJ ::::: good
# morning ----> NOUN ::::: morning
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Good ----> ADJ ::::: good
# morning ----> NOUN ::::: morning
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# It ----> PRON ::::: it
# hurts ----> VERB ::::: hurt
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# need ----> VERB ::::: need
# to ----> PART ::::: to
# do ----> VERB ::::: do
# something ----> PRON ::::: something
# to ----> PART ::::: to
# lift ----> VERB ::::: lift
# her ----> PRON ::::: her
# mood ----> NOUN ::::: mood
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Yor ----> PROPN ::::: Yor
# , ----> PUNCT ::::: ,
# today ----> NOUN ::::: today
# is ----> AUX ::::: be
# our ----> PRON ::::: our
# day ----> NOUN ::::: day
# off ----> ADV ::::: off
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# So ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# will ----> AUX ::::: will
# you ----> PRON ::::: you
# go ----> VERB ::::: go
# out ----> ADP ::::: out
# on ----> ADP ::::: on
# a ----> DET ::::: a
# date ----> NOUN ::::: date
# with ----> ADP ::::: with
# me ----> PRON ::::: I
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Date ----> NOUN ::::: date
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# always ----> ADV ::::: always
# helping ----> VERB ::::: help
# me ----> PRON ::::: I
# by ----> ADP ::::: by
# taking ----> VERB ::::: take
# care ----> NOUN ::::: care
#
#
#  ----> SPACE :::::
#
#
# of ----> ADP ::::: of
# the ----> DET ::::: the
# house ----> NOUN ::::: house
# and ----> CCONJ ::::: and
# looking ----> VERB ::::: look
# after ----> ADP ::::: after
# Anya ----> PROPN ::::: Anya
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# So ----> ADV ::::: so
# I ----> PRON ::::: I
# want ----> VERB ::::: want
# you ----> PRON ::::: you
# to ----> PART ::::: to
# relax ----> VERB ::::: relax
#
#
#  ----> SPACE :::::
#
#
# and ----> CCONJ ::::: and
# let ----> VERB ::::: let
# loose ----> ADJ ::::: loose
# today ----> NOUN ::::: today
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# A ----> DET ::::: a
# date ----> NOUN ::::: date
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# My ----> PRON ::::: my
# boyfriend ----> NOUN ::::: boyfriend
# took ----> VERB ::::: take
# me ----> PRON ::::: I
# on ----> ADP ::::: on
# a ----> DET ::::: a
# cruise ----> NOUN ::::: cruise
#
#
#  ----> SPACE :::::
#
#
# for ----> ADP ::::: for
# our ----> PRON ::::: our
# date ----> NOUN ::::: date
# the ----> DET ::::: the
# other ----> ADJ ::::: other
# day ----> NOUN ::::: day
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# What ----> PRON ::::: what
# kind ----> NOUN ::::: kind
# of ----> ADP ::::: of
# dates ----> NOUN ::::: date
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# go ----> VERB ::::: go
# on ----> ADP ::::: on
# , ----> PUNCT ::::: ,
# Yor ----> PROPN ::::: Yor
# ? ----> PROPN ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# We ----> PRON ::::: we
# 've ----> AUX ::::: have
# never ----> ADV ::::: never
# gone ----> VERB ::::: go
# on ----> ADP ::::: on
# a ----> DET ::::: a
# date ----> NOUN ::::: date
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Liar ----> PROPN ::::: Liar
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# normal ----> ADJ ::::: normal
# to ----> PART ::::: to
# go ----> VERB ::::: go
# on ----> ADP ::::: on
# dates ----> NOUN ::::: date
#
#
#  ----> SPACE :::::
#
#
# even ----> ADV ::::: even
# after ----> SCONJ ::::: after
# you ----> PRON ::::: you
# get ----> AUX ::::: get
# married ----> VERB ::::: marry
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Oh ----> INTJ ::::: oh
# ... ----> PUNCT ::::: ...
# well ----> ADV ::::: well
# ... ----> PUNCT ::::: ...
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# should ----> AUX ::::: should
# probably ----> ADV ::::: probably
# gain ----> VERB ::::: gain
#
#
#  ----> SPACE :::::
#
#
# some ----> DET ::::: some
# experience ----> NOUN ::::: experience
# of ----> ADP ::::: of
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# a ----> DET ::::: a
# date ----> NOUN ::::: date
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# or ----> CCONJ ::::: or
# people ----> NOUN ::::: people
# might ----> AUX ::::: might
# suspect ----> VERB ::::: suspect
#
#
#  ----> SPACE :::::
#
#
# that ----> SCONJ ::::: that
# we ----> PRON ::::: we
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# really ----> ADV ::::: really
# a ----> DET ::::: a
# married ----> ADJ ::::: married
# couple ----> NOUN ::::: couple
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# We ----> PRON ::::: we
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# have ----> VERB ::::: have
# to ----> PART ::::: to
# go ----> VERB ::::: go
#
#
#  ----> SPACE :::::
#
#
# if ----> SCONJ ::::: if
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# feeling ----> VERB ::::: feel
# well ----> ADV ::::: well
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# will ----> AUX ::::: will
# go ----> VERB ::::: go
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# a ----> DET ::::: a
# great ----> ADJ ::::: great
# opportunity ----> NOUN ::::: opportunity
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# so ----> SCONJ ::::: so
# I ----> PRON ::::: I
# will ----> AUX ::::: will
# use ----> VERB ::::: use
# this ----> DET ::::: this
# chance ----> NOUN ::::: chance
# to ----> PART ::::: to
# learn ----> VERB ::::: learn
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Learn ----> VERB ::::: learn
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# get ----> AUX ::::: get
# dressed ----> VERB ::::: dress
# right ----> ADV ::::: right
# away ----> ADV ::::: away
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Anya ----> PROPN ::::: Anya
# wants ----> VERB ::::: want
# to ----> PART ::::: to
# go ----> VERB ::::: go
# too ----> ADV ::::: too
# ! ----> PUNCT ::::: !
# A ----> DET ::::: a
# date ----> NOUN ::::: date
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# How ----> SCONJ ::::: how
# exciting ----> ADJ ::::: exciting
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Sorry ----> ADJ ::::: sorry
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# coming ----> VERB ::::: come
# with ----> ADP ::::: with
# us ----> PRON ::::: we
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# a ----> DET ::::: a
# date ----> NOUN ::::: date
# , ----> PUNCT ::::: ,
# after ----> ADV ::::: after
# all ----> ADV ::::: all
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# How ----> SCONJ ::::: how
# sad ----> ADJ ::::: sad
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Have ----> VERB ::::: have
# fun ----> NOUN ::::: fun
# at ----> ADP ::::: at
# home ----> NOUN ::::: home
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Come ----> VERB ::::: come
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Listen ----> VERB ::::: listen
# up ----> ADP ::::: up
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# How ----> SCONJ ::::: how
# many ----> ADJ ::::: many
# times ----> NOUN ::::: time
# do ----> AUX ::::: do
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# you ----> PRON ::::: you
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# your ----> PRON ::::: your
# informant ----> NOUN ::::: informant
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Not ----> PART ::::: not
# someone ----> PRON ::::: someone
# you ----> PRON ::::: you
# call ----> VERB ::::: call
# for ----> ADP ::::: for
# odd ----> ADJ ::::: odd
# jobs ----> NOUN ::::: job
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# no ----> DET ::::: no
# choice ----> NOUN ::::: choice
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# leave ----> VERB ::::: leave
# Anya ----> PROPN ::::: Anya
#
#
#  ----> SPACE :::::
#
#
# home ----> ADV ::::: home
# all ----> PRON ::::: all
# by ----> ADP ::::: by
# herself ----> PRON ::::: herself
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# an ----> DET ::::: an
# important ----> ADJ ::::: important
# part ----> NOUN ::::: part
# of ----> ADP ::::: of
# the ----> DET ::::: the
# mission ----> NOUN ::::: mission
#
#
#  ----> SPACE :::::
#
#
# to ----> PART ::::: to
# keep ----> VERB ::::: keep
# the ----> DET ::::: the
# family ----> NOUN ::::: family
# together ----> ADV ::::: together
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# said ----> VERB ::::: say
# you ----> PRON ::::: you
# want ----> VERB ::::: want
# to ----> PART ::::: to
# invent ----> VERB ::::: invent
#
#
#  ----> SPACE :::::
#
#
# some ----> DET ::::: some
# new ----> ADJ ::::: new
# spying ----> NOUN ::::: spying
# gadgets ----> NOUN ::::: gadget
# , ----> PUNCT ::::: ,
# right ----> ADJ ::::: right
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# This ----> DET ::::: this
# payment ----> NOUN ::::: payment
# will ----> AUX ::::: will
# help ----> VERB ::::: help
# with ----> ADP ::::: with
# that ----> PRON ::::: that
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# keep ----> VERB ::::: keep
# on ----> ADP ::::: on
# using ----> VERB ::::: use
# my ----> PRON ::::: my
# weakness ----> NOUN ::::: weakness
# against ----> ADP ::::: against
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# All ----> ADV ::::: all
# right ----> ADV ::::: right
# . ----> PUNCT ::::: .
# Shall ----> AUX ::::: shall
# we ----> PRON ::::: we
# go ----> VERB ::::: go
# , ----> PUNCT ::::: ,
# Yor ----> PROPN ::::: Yor
# ? ----> PROPN ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Your ----> PRON ::::: your
# hand ----> NOUN ::::: hand
# , ----> PUNCT ::::: ,
# please ----> INTJ ::::: please
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Last ----> ADJ ::::: last
# night ----> NOUN ::::: night
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# came ----> VERB ::::: come
# up ----> ADP ::::: up
# with ----> ADP ::::: with
# 862 ----> NUM ::::: 862
# date ----> NOUN ::::: date
# plans ----> NOUN ::::: plan
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# that ----> SCONJ ::::: that
# Yor ----> PROPN ::::: Yor
# might ----> AUX ::::: might
# enjoy ----> VERB ::::: enjoy
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# all ----> PRON ::::: all
# set ----> VERB ::::: set
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# sorry ----> ADJ ::::: sorry
# , ----> PUNCT ::::: ,
# Loid ----> PROPN ::::: Loid
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# sustain ----> VERB ::::: sustain
# more ----> ADJ ::::: more
# damage ----> NOUN ::::: damage
# to ----> ADP ::::: to
# my ----> PRON ::::: my
# butt ----> NOUN ::::: butt
#
#
#  ----> SPACE :::::
#
#
# if ----> SCONJ ::::: if
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# to ----> PART ::::: to
# sit ----> VERB ::::: sit
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'd ----> AUX ::::: would
# like ----> VERB ::::: like
# to ----> PART ::::: to
# walk ----> VERB ::::: walk
# on ----> ADP ::::: on
# our ----> PRON ::::: our
# date ----> NOUN ::::: date
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# She ----> PRON ::::: she
# 's ----> AUX ::::: be
# mad ----> ADJ ::::: mad
# ? ----> PUNCT ::::: ?
# She ----> PRON ::::: she
# 's ----> AUX ::::: be
# still ----> ADV ::::: still
# mad ----> ADJ ::::: mad
# ? ----> PROPN ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Dammit ----> PROPN ::::: Dammit
# . ----> PUNCT ::::: .
# That ----> PRON ::::: that
# takes ----> VERB ::::: take
# out ----> ADP ::::: out
# 794 ----> NUM ::::: 794
# date ----> NOUN ::::: date
# plans ----> NOUN ::::: plan
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Good ----> ADJ ::::: good
# idea ----> NOUN ::::: idea
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Let ----> VERB ::::: let
# 's ----> PRON ::::: us
# just ----> ADV ::::: just
# take ----> VERB ::::: take
# it ----> PRON ::::: it
# easy ----> ADJ ::::: easy
#
#
#  ----> SPACE :::::
#
#
# and ----> CCONJ ::::: and
# go ----> VERB ::::: go
# for ----> ADP ::::: for
# a ----> DET ::::: a
# stroll ----> NOUN ::::: stroll
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# worried ----> ADJ ::::: worried
# about ----> ADP ::::: about
# Father ----> PROPN ::::: Father
# and ----> CCONJ ::::: and
# Mother ----> PROPN ::::: Mother
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# That ----> DET ::::: that
# guy ----> NOUN ::::: guy
# 's ----> AUX ::::: be
# hopeless ----> ADJ ::::: hopeless
# if ----> SCONJ ::::: if
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# got ----> VERB ::::: get
#
#
#  ----> SPACE :::::
#
#
# a ----> DET ::::: a
# little ----> ADJ ::::: little
# kid ----> NOUN ::::: kid
# worrying ----> VERB ::::: worry
# about ----> ADP ::::: about
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Little ----> ADJ ::::: little
# kids ----> NOUN ::::: kid
# should ----> AUX ::::: should
# go ----> VERB ::::: go
# inside ----> ADV ::::: inside
#
#
#  ----> SPACE :::::
#
#
# and ----> CCONJ ::::: and
# watch ----> VERB ::::: watch
# anime ----> NOUN ::::: anime
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Go ----> VERB ::::: go
# , ----> PUNCT ::::: ,
# Bondman ----> PROPN ::::: Bondman
# ! ----> PUNCT ::::: !
# Tail ----> NOUN ::::: tail
# the ----> DET ::::: the
# target ----> NOUN ::::: target
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# and ----> CCONJ ::::: and
# maintain ----> VERB ::::: maintain
# world ----> NOUN ::::: world
# peace ----> NOUN ::::: peace
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Scruffy ----> PROPN ::::: Scruffy
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Anya ----> PROPN ::::: Anya
# wants ----> VERB ::::: want
# to ----> PART ::::: to
# tail ----> VERB ::::: tail
# Father ----> PROPN ::::: Father
# and ----> CCONJ ::::: and
# Mother ----> PROPN ::::: Mother
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# What ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
# That ----> PRON ::::: that
# sounds ----> VERB ::::: sound
# like ----> ADP ::::: like
# so ----> ADV ::::: so
# much ----> ADJ ::::: much
# fun ----> NOUN ::::: fun
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# Shall ----> AUX ::::: shall
# we ----> PRON ::::: we
# do ----> VERB ::::: do
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Let ----> VERB ::::: let
# 's ----> PRON ::::: us
# tail ----> VERB ::::: tail
# them ----> PRON ::::: they
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Your ----> PRON ::::: your
# dad ----> NOUN ::::: dad
# is ----> AUX ::::: be
# pretty ----> ADV ::::: pretty
# sharp ----> ADJ ::::: sharp
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# So ----> ADV ::::: so
# let ----> VERB ::::: let
# 's ----> PRON ::::: us
# disguise ----> VERB ::::: disguise
# ourselves ----> PRON ::::: ourselves
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# and ----> CCONJ ::::: and
# be ----> AUX ::::: be
# careful ----> ADJ ::::: careful
# . ----> PUNCT ::::: .
# Go ----> VERB ::::: go
# change ----> VERB ::::: change
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# sir ----> PROPN ::::: sir
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# That ----> DET ::::: that
# outfit ----> NOUN ::::: outfit
# makes ----> VERB ::::: make
# you ----> PRON ::::: you
# stand ----> VERB ::::: stand
# out ----> ADP ::::: out
# even ----> ADV ::::: even
# more ----> ADJ ::::: more
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# No ----> DET ::::: no
# problem ----> NOUN ::::: problem
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# If ----> SCONJ ::::: if
# you ----> PRON ::::: you
# say ----> VERB ::::: say
# so ----> ADV ::::: so
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# in ----> ADP ::::: in
# charge ----> NOUN ::::: charge
# of ----> ADP ::::: of
# guarding ----> VERB ::::: guard
# the ----> DET ::::: the
# house ----> NOUN ::::: house
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# my ----> PRON ::::: my
# capable ----> ADJ ::::: capable
# agents ----> NOUN ::::: agent
# of ----> ADP ::::: of
#
#
#  ----> SPACE :::::
#
#
# the ----> DET ::::: the
# secret ----> ADJ ::::: secret
# organization ----> NOUN ::::: organization
# P2 ----> PROPN ::::: P2
# . ----> PUNCT ::::: .
# Bond ----> PROPN ::::: Bond
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Director ----> PROPN ::::: Director
# Kimera ----> PROPN ::::: Kimera
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# and ----> CCONJ ::::: and
# Agent ----> PROPN ::::: Agent
# Penguin ----> PROPN ::::: Penguin
# Man ----> PROPN ::::: Man
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Hey ----> INTJ ::::: hey
# Twilight ----> PROPN ::::: Twilight
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# you ----> PRON ::::: you
# 've ----> AUX ::::: have
# charmed ----> VERB ::::: charm
# countless ----> ADJ ::::: countless
# women ----> NOUN ::::: woman
#
#
#  ----> SPACE :::::
#
#
# with ----> ADP ::::: with
# your ----> PRON ::::: your
# art ----> NOUN ::::: art
# of ----> ADP ::::: of
# seduction ----> NOUN ::::: seduction
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# my ----> PRON ::::: my
# chance ----> NOUN ::::: chance
# to ----> PART ::::: to
# see ----> VERB ::::: see
# you ----> PRON ::::: you
# in ----> ADP ::::: in
# action ----> NOUN ::::: action
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# too ----> ADV ::::: too
# far ----> ADV ::::: far
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# read ----> VERB ::::: read
# his ----> PRON ::::: his
# mind ----> NOUN ::::: mind
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# What ----> PRON ::::: what
# are ----> AUX ::::: be
# they ----> PRON ::::: they
# doing ----> VERB ::::: do
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# CAUGHT ----> VERB ::::: catch
# WITHIN ----> ADP ::::: within
# SECONDS ----> NOUN ::::: second
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Are ----> AUX ::::: be
# they ----> PRON ::::: they
# pretending ----> VERB ::::: pretend
# to ----> PART ::::: to
# be ----> AUX ::::: be
# spies ----> NOUN ::::: spy
# ? ----> PUNCT ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# so ----> ADV ::::: so
# fun ----> ADJ ::::: fun
# about ----> ADP ::::: about
# that ----> PRON ::::: that
# ? ----> PUNCT ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# view ----> VERB ::::: view
# this ----> PRON ::::: this
# as ----> ADP ::::: as
# part ----> NOUN ::::: part
# of ----> ADP ::::: of
# my ----> PRON ::::: my
# mission ----> NOUN ::::: mission
#
#
#  ----> SPACE :::::
#
#
# to ----> PART ::::: to
# maintain ----> VERB ::::: maintain
# a ----> DET ::::: a
# happy ----> ADJ ::::: happy
# family ----> NOUN ::::: family
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# and ----> CCONJ ::::: and
# pretend ----> VERB ::::: pretend
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# notice ----> VERB ::::: notice
# them ----> PRON ::::: they
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# And ----> CCONJ ::::: and
# Anya ----> PROPN ::::: Anya
# should ----> AUX ::::: should
# be ----> AUX ::::: be
# safe ----> ADJ ::::: safe
# as ----> ADV ::::: as
# long ----> ADV ::::: long
# as ----> SCONJ ::::: as
# Franky ----> PROPN ::::: Franky
#
#
#  ----> SPACE :::::
#
#
# is ----> AUX ::::: be
# with ----> ADP ::::: with
# her ----> PRON ::::: she
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# Loid ----> PROPN ::::: Loid
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# nothing ----> PRON ::::: nothing
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# More ----> ADV ::::: more
# importantly ----> ADV ::::: importantly
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# to ----> PART ::::: to
# lift ----> VERB ::::: lift
# Yor ----> PROPN ::::: Yor
# 's ----> PART ::::: 's
# mood ----> NOUN ::::: mood
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Shall ----> AUX ::::: shall
# we ----> PRON ::::: we
# do ----> VERB ::::: do
# some ----> DET ::::: some
# shopping ----> NOUN ::::: shopping
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# CENTRAL ----> PROPN ::::: CENTRAL
# MALL ----> PROPN ::::: MALL
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Yor ----> PROPN ::::: Yor
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# have ----> VERB ::::: have
# a ----> DET ::::: a
# nice ----> ADJ ::::: nice
# figure ----> NOUN ::::: figure
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# so ----> ADV ::::: so
# I ----> PRON ::::: I
# bet ----> VERB ::::: bet
# you ----> PRON ::::: you
# 'll ----> AUX ::::: will
# look ----> VERB ::::: look
# good ----> ADJ ::::: good
# in ----> ADP ::::: in
# pants ----> NOUN ::::: pant
# too ----> ADV ::::: too
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Would ----> AUX ::::: would
# you ----> PRON ::::: you
# like ----> VERB ::::: like
# to ----> PART ::::: to
# try ----> VERB ::::: try
# it ----> PRON ::::: it
# on ----> ADP ::::: on
# ? ----> PUNCT ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# If ----> SCONJ ::::: if
# I ----> PRON ::::: I
# wear ----> VERB ::::: wear
# anything ----> PRON ::::: anything
# that ----> PRON ::::: that
# tight ----> ADV ::::: tight
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# it ----> PRON ::::: it
# 'll ----> AUX ::::: will
# put ----> VERB ::::: put
# pressure ----> NOUN ::::: pressure
# on ----> ADP ::::: on
# my ----> PRON ::::: my
# wound ----> NOUN ::::: wound
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# pain ----> NOUN ::::: pain
# will ----> AUX ::::: will
# make ----> VERB ::::: make
# me ----> PRON ::::: I
# faint ----> ADJ ::::: faint
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Not ----> PART ::::: not
# a ----> DET ::::: a
# chance ----> NOUN ::::: chance
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Sorry ----> ADJ ::::: sorry
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# MOVIE ----> PROPN ::::: MOVIE
# THEATER ----> PROPN ::::: THEATER
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# love ----> NOUN ::::: love
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# - ----> PUNCT ::::: -
# Look ----> VERB ::::: look
# into ----> ADP ::::: into
# my ----> PRON ::::: my
# eyes ----> NOUN ::::: eye
# and ----> CCONJ ::::: and
# tell ----> VERB ::::: tell
# me ----> PRON ::::: I
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# a ----> DET ::::: a
# lie ----> NOUN ::::: lie
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Yor ----> PROPN ::::: Yor
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Why ----> SCONJ ::::: why
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# you ----> PRON ::::: you
# sit ----> VERB ::::: sit
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# attracting ----> VERB ::::: attract
# attention ----> NOUN ::::: attention
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# No ----> DET ::::: no
# thanks ----> NOUN ::::: thank
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# If ----> SCONJ ::::: if
# I ----> PRON ::::: I
# sit ----> VERB ::::: sit
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# butt ----> NOUN ::::: butt
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# CLUB ----> NOUN ::::: club
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# If ----> SCONJ ::::: if
# I ----> PRON ::::: I
# sit ----> VERB ::::: sit
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# butt ----> NOUN ::::: butt
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Yor ----> PROPN ::::: Yor
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# dangerous ----> ADJ ::::: dangerous
# , ----> PUNCT ::::: ,
# so ----> SCONJ ::::: so
# you ----> PRON ::::: you
# should ----> AUX ::::: should
# sit ----> VERB ::::: sit
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# But ----> CCONJ ::::: but
# if ----> SCONJ ::::: if
# I ----> PRON ::::: I
# sit ----> VERB ::::: sit
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# butt ----> NOUN ::::: butt
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# SPA ----> PROPN ::::: SPA
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# My ----> PRON ::::: my
# butt ----> NOUN ::::: butt
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# ZOO ----> PROPN ::::: ZOO
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# What ----> PRON ::::: what
# am ----> AUX ::::: be
# I ----> PRON ::::: I
# to ----> PART ::::: to
# do ----> VERB ::::: do
# ? ----> PUNCT ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# concentrate ----> VERB ::::: concentrate
# on ----> ADP ::::: on
# this ----> DET ::::: this
# date ----> NOUN ::::: date
# at ----> ADV ::::: at
# all ----> ADV ::::: all
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Even ----> ADV ::::: even
# though ----> SCONJ ::::: though
# Loid ----> PROPN ::::: Loid
# is ----> AUX ::::: be
# teaching ----> VERB ::::: teach
# me ----> PRON ::::: I
#
#
#  ----> SPACE :::::
#
#
# so ----> ADV ::::: so
# many ----> ADJ ::::: many
# things ----> NOUN ::::: thing
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# What ----> PRON ::::: what
# should ----> AUX ::::: should
# I ----> PRON ::::: I
# do ----> VERB ::::: do
# ? ----> PUNCT ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Not ----> PART ::::: not
# only ----> ADV ::::: only
# have ----> AUX ::::: have
# I ----> PRON ::::: I
# not ----> PART ::::: not
# lifted ----> VERB ::::: lift
# her ----> PRON ::::: her
# mood ----> NOUN ::::: mood
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# 've ----> AUX ::::: have
# made ----> VERB ::::: make
# it ----> PRON ::::: it
# worse ----> ADJ ::::: bad
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Did ----> AUX ::::: do
# I ----> PRON ::::: I
# pick ----> VERB ::::: pick
# all ----> DET ::::: all
# the ----> DET ::::: the
# wrong ----> ADJ ::::: wrong
# choices ----> NOUN ::::: choice
# ? ----> PUNCT ::::: ?
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# What ----> PRON ::::: what
# is ----> AUX ::::: be
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
# What ----> PRON ::::: what
# does ----> AUX ::::: do
# Yor ----> PROPN ::::: Yor
# like ----> ADJ ::::: like
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Did ----> AUX ::::: do
# I ----> PRON ::::: I
# not ----> PART ::::: not
# do ----> VERB ::::: do
# enough ----> ADJ ::::: enough
# research ----> NOUN ::::: research
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Loid ----> PROPN ::::: Loid
# is ----> AUX ::::: be
# always ----> ADV ::::: always
# acting ----> VERB ::::: act
# so ----> ADV ::::: so
# cool ----> ADJ ::::: cool
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# but ----> CCONJ ::::: but
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# failing ----> VERB ::::: fail
# so ----> ADV ::::: so
# badly ----> ADV ::::: badly
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# How ----> SCONJ ::::: how
# pathetic ----> ADJ ::::: pathetic
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Scruffy ----> PROPN ::::: Scruffy
# , ----> PUNCT ::::: ,
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# a ----> DET ::::: a
# mean ----> ADJ ::::: mean
# person ----> NOUN ::::: person
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Not ----> PART ::::: not
# at ----> ADV ::::: at
# all ----> ADV ::::: all
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# the ----> DET ::::: the
# right ----> NOUN ::::: right
# to ----> PART ::::: to
# sneer ----> VERB ::::: sneer
#
#
#  ----> SPACE :::::
#
#
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# get ----> VERB ::::: get
# any ----> DET ::::: any
# girls ----> NOUN ::::: girl
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# How ----> SCONJ ::::: how
# pitiful ----> ADJ ::::: pitiful
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# What ----> PRON ::::: what
# did ----> AUX ::::: do
# you ----> PRON ::::: you
# say ----> VERB ::::: say
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# so ----> ADV ::::: so
# obtrusive ----> ADJ ::::: obtrusive
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# sure ----> ADJ ::::: sure
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# tired ----> ADJ ::::: tired
# . ----> PUNCT ::::: .
# How ----> SCONJ ::::: how
# about ----> ADP ::::: about
# dinner ----> NOUN ::::: dinner
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Sure ----> ADJ ::::: sure
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mr. ----> PROPN ::::: Mr.
# Forger ----> PROPN ::::: Forger
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# have ----> VERB ::::: have
# your ----> PRON ::::: your
# reservation ----> NOUN ::::: reservation
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Please ----> INTJ ::::: please
# sit ----> VERB ::::: sit
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# We ----> PRON ::::: we
# ...
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# safe ----> ADJ ::::: safe
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# What ----> PRON ::::: what
# a ----> DET ::::: a
# relief ----> NOUN ::::: relief
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# would ----> AUX ::::: would
# n't ----> PART ::::: not
# have ----> AUX ::::: have
# been ----> AUX ::::: be
# able ----> ADJ ::::: able
#
#
#  ----> SPACE :::::
#
#
# to ----> PART ::::: to
# live ----> VERB ::::: live
# without ----> ADP ::::: without
# you ----> PRON ::::: you
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# My ----> PRON ::::: my
# Daisy ----> PROPN ::::: Daisy
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# so ----> ADV ::::: so
# sorry ----> ADJ ::::: sorry
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# A ----> DET ::::: a
# serious ----> ADJ ::::: serious
# looking ----> NOUN ::::: looking
# guy ----> NOUN ::::: guy
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# and ----> CCONJ ::::: and
# a ----> DET ::::: a
# huge ----> ADJ ::::: huge
# , ----> PUNCT ::::: ,
# super ----> ADJ ::::: super
# thin ----> ADJ ::::: thin
# dog ----> NOUN ::::: dog
#
#
#  ----> SPACE :::::
#
#
# rescued ----> VERB ::::: rescue
# your ----> PRON ::::: your
# puppy ----> NOUN ::::: puppy
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# They ----> PRON ::::: they
# really ----> ADV ::::: really
# deserve ----> VERB ::::: deserve
# a ----> DET ::::: a
# medal ----> NOUN ::::: medal
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Where ----> SCONJ ::::: where
# did ----> AUX ::::: do
# they ----> PRON ::::: they
# go ----> VERB ::::: go
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Let ----> VERB ::::: let
# me ----> PRON ::::: I
# go ----> VERB ::::: go
# look ----> VERB ::::: look
# for ----> ADP ::::: for
# them ----> PRON ::::: they
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Let ----> VERB ::::: let
# 's ----> PRON ::::: us
# go ----> VERB ::::: go
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# It ----> PRON ::::: it
# wo ----> AUX ::::: will
# n't ----> PART ::::: not
# be ----> AUX ::::: be
# good ----> ADJ ::::: good
# for ----> ADP ::::: for
# either ----> PRON ::::: either
# of ----> ADP ::::: of
# us ----> PRON ::::: we
#
#
#  ----> SPACE :::::
#
#
# to ----> PART ::::: to
# be ----> AUX ::::: be
# in ----> ADP ::::: in
# the ----> DET ::::: the
# newspaper ----> NOUN ::::: newspaper
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Let ----> VERB ::::: let
# 's ----> PRON ::::: us
# reward ----> VERB ::::: reward
# this ----> DET ::::: this
# doggie ----> NOUN ::::: doggie
# for ----> ADP ::::: for
# his ----> PRON ::::: his
# work ----> NOUN ::::: work
#
#
#  ----> SPACE :::::
#
#
# with ----> ADP ::::: with
# a ----> DET ::::: a
# year ----> NOUN ::::: year
# 's ----> PART ::::: 's
# worth ----> NOUN ::::: worth
# of ----> ADP ::::: of
# meat ----> NOUN ::::: meat
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# did ----> VERB ::::: do
# well ----> ADV ::::: well
# ! ----> PUNCT ::::: !
# You ----> PRON ::::: you
# were ----> AUX ::::: be
# amazing ----> ADJ ::::: amazing
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# supposed ----> VERB ::::: suppose
# to ----> PART ::::: to
# bite ----> VERB ::::: bite
# the ----> DET ::::: the
# arm ----> NOUN ::::: arm
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# not ----> PART ::::: not
# the ----> DET ::::: the
# leg ----> NOUN ::::: leg
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# be ----> AUX ::::: be
# reckless ----> ADJ ::::: reckless
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# people ----> NOUN ::::: people
# at ----> ADP ::::: at
# home ----> NOUN ::::: home
# who ----> PRON ::::: who
# will ----> AUX ::::: will
# be ----> AUX ::::: be
# sad ----> ADJ ::::: sad
#
#
#  ----> SPACE :::::
#
#
# if ----> SCONJ ::::: if
# you ----> PRON ::::: you
# die ----> VERB ::::: die
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# sorry ----> ADJ ::::: sorry
# too ----> ADV ::::: too
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Your ----> PRON ::::: your
# role ----> NOUN ::::: role
# as ----> ADP ::::: as
# a ----> DET ::::: a
# working ----> VERB ::::: work
# dog ----> NOUN ::::: dog
#
#
#  ----> SPACE :::::
#
#
# should ----> AUX ::::: should
# only ----> ADV ::::: only
# come ----> VERB ::::: come
# second ----> ADV ::::: second
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Understand ----> VERB ::::: understand
# that ----> SCONJ ::::: that
# first ----> ADJ ::::: first
# and ----> CCONJ ::::: and
# foremost ----> ADV ::::: foremost
# , ----> PUNCT ::::: ,
#
#
#  ----> SPACE :::::
#
#
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# a ----> DET ::::: a
# member ----> NOUN ::::: member
# of ----> ADP ::::: of
# the ----> DET ::::: the
# Forger ----> PROPN ::::: Forger
# family ----> NOUN ::::: family
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Got ----> VERB ::::: get
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# not ----> PART ::::: not
# hurt ----> VERB ::::: hurt
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# must ----> AUX ::::: must
# have ----> AUX ::::: have
# breathed ----> VERB ::::: breathe
# in ----> ADP ::::: in
# a ----> DET ::::: a
# lot ----> NOUN ::::: lot
# of ----> ADP ::::: of
# smoke ----> NOUN ::::: smoke
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Let ----> VERB ::::: let
# 's ----> PRON ::::: us
# get ----> VERB ::::: get
# you ----> PRON ::::: you
# checked ----> VERB ::::: check
# out ----> ADP ::::: out
# at ----> ADP ::::: at
# the ----> DET ::::: the
# vet ----> NOUN ::::: vet
#
#
#  ----> SPACE :::::
#
#
# just ----> ADV ::::: just
# in ----> ADP ::::: in
# case ----> NOUN ::::: case
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# is ----> AUX ::::: be
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
# Stop ----> VERB ::::: stop
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# get ----> AUX ::::: get
# carried ----> VERB ::::: carry
# away ----> ADV ::::: away
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# I ----> PRON ::::: I
# just ----> ADV ::::: just
# want ----> VERB ::::: want
# the ----> DET ::::: the
# Forger ----> PROPN ::::: Forger
# family ----> NOUN ::::: family
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# to ----> PART ::::: to
# stay ----> VERB ::::: stay
# together ----> ADV ::::: together
# for ----> ADP ::::: for
# my ----> PRON ::::: my
# best ----> ADJ ::::: good
# interests ----> NOUN ::::: interest
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# have ----> VERB ::::: have
# any ----> DET ::::: any
# extra ----> ADJ ::::: extra
# missions ----> NOUN ::::: mission
# tomorrow ----> NOUN ::::: tomorrow
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# so ----> ADV ::::: so
# let ----> VERB ::::: let
# 's ----> PRON ::::: us
# all ----> PRON ::::: all
# go ----> VERB ::::: go
# to ----> ADP ::::: to
# the ----> DET ::::: the
# dog ----> NOUN ::::: dog
# park ----> NOUN ::::: park
# together ----> ADV ::::: together
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# 've ----> AUX ::::: have
# been ----> AUX ::::: be
# all ----> ADV ::::: all
# alone ----> ADJ ::::: alone
# lately ----> ADV ::::: lately
#
#
#  ----> SPACE :::::
#
#
# staying ----> VERB ::::: stay
# home ----> ADV ::::: home
# by ----> ADP ::::: by
# yourself ----> PRON ::::: yourself
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Why ----> SCONJ ::::: why
# does ----> AUX ::::: do
# your ----> PRON ::::: your
# bark ----> NOUN ::::: bark
# change ----> VERB ::::: change
#
#
#  ----> SPACE :::::
#
#
# when ----> SCONJ ::::: when
# you ----> PRON ::::: you
# get ----> VERB ::::: get
# wet ----> ADJ ::::: wet
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# did ----> VERB ::::: do
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# Is ----> AUX ::::: be
# that ----> PRON ::::: that
# a ----> DET ::::: a
# knife ----> NOUN ::::: knife
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Oh ----> INTJ ::::: oh
# ? ----> ADP ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# a ----> DET ::::: a
# penguin ----> NOUN ::::: penguin
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Origami ----> PROPN ::::: Origami
# is ----> AUX ::::: be
# pretty ----> ADV ::::: pretty
# difficult ----> ADJ ::::: difficult
# , ----> PUNCT ::::: ,
# huh ----> INTJ ::::: huh
# ? ----> ADP ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Oh ----> INTJ ::::: oh
# yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# how ----> SCONJ ::::: how
# about ----> ADP ::::: about
# something ----> PRON ::::: something
# like ----> ADP ::::: like
# this ----> PRON ::::: this
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Ta ----> PROPN ::::: Ta
# - ----> PUNCT ::::: -
# da ----> PROPN ::::: da
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Oh ----> INTJ ::::: oh
# ... ----> PUNCT ::::: ...
# I ----> PRON ::::: I
# cut ----> VERB ::::: cut
# it ----> PRON ::::: it
# a ----> DET ::::: a
# bit ----> NOUN ::::: bit
# too ----> ADV ::::: too
# much ----> ADJ ::::: much
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# back ----> ADV ::::: back
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Welcome ----> VERB ::::: welcome
# back ----> ADP ::::: back
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bond ----> PROPN ::::: Bond
# ! ----> PUNCT ::::: !
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# all ----> ADV ::::: all
# wilted ----> ADJ ::::: wilted
# and ----> CCONJ ::::: and
# shriveled ----> ADJ ::::: shriveled
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Oh ----> INTJ ::::: oh
# my ----> INTJ ::::: my
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# happened ----> VERB ::::: happen
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# there ----> PRON ::::: there
# was ----> VERB ::::: be
# a ----> DET ::::: a
# bit ----> NOUN ::::: bit
# of ----> ADP ::::: of
# an ----> DET ::::: an
# accident ----> NOUN ::::: accident
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# We ----> PRON ::::: we
# got ----> AUX ::::: get
# splashed ----> VERB ::::: splash
# with ----> ADP ::::: with
# water ----> NOUN ::::: water
#
#
#  ----> SPACE :::::
#
#
# on ----> ADP ::::: on
# the ----> DET ::::: the
# way ----> NOUN ::::: way
# home ----> ADV ::::: home
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# see ----> VERB ::::: see
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# His ----> PRON ::::: his
# bark ----> NOUN ::::: bark
# sounds ----> VERB ::::: sound
# different ----> ADJ ::::: different
# too ----> ADV ::::: too
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# worry ----> VERB ::::: worry
# , ----> PUNCT ::::: ,
# Anya ----> PROPN ::::: Anya
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# what ----> PRON ::::: what
# happens ----> VERB ::::: happen
# to ----> ADP ::::: to
# Bond ----> NOUN ::::: bond
#
#
#  ----> SPACE :::::
#
#
# when ----> SCONJ ::::: when
# he ----> PRON ::::: he
# gets ----> VERB ::::: get
# wet ----> ADJ ::::: wet
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# He ----> PRON ::::: he
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# his ----> PRON ::::: his
# fluffy ----> ADJ ::::: fluffy
# self ----> NOUN ::::: self
#
#
#  ----> SPACE :::::
#
#
# once ----> SCONJ ::::: once
# his ----> PRON ::::: his
# fur ----> NOUN ::::: fur
# dries ----> NOUN ::::: dry
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# He ----> PRON ::::: he
# rescued ----> VERB ::::: rescue
# a ----> DET ::::: a
# puppy ----> NOUN ::::: puppy
# from ----> ADP ::::: from
# a ----> DET ::::: a
# fire ----> NOUN ::::: fire
# , ----> PUNCT ::::: ,
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# and ----> CCONJ ::::: and
# caught ----> VERB ::::: catch
# an ----> DET ::::: an
# arsonist ----> NOUN ::::: arsonist
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# But ----> CCONJ ::::: but
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# tell ----> VERB ::::: tell
# them ----> PRON ::::: they
#
#
#  ----> SPACE :::::
#
#
# what ----> PRON ::::: what
# really ----> ADV ::::: really
# happened ----> VERB ::::: happen
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Father ----> PROPN ::::: Father
# and ----> CCONJ ::::: and
# Bond ----> PROPN ::::: Bond
# achieved ----> VERB ::::: achieve
#
#
#  ----> SPACE :::::
#
#
# great ----> ADJ ::::: great
# things ----> NOUN ::::: thing
# during ----> ADP ::::: during
# their ----> PRON ::::: their
# walk ----> NOUN ::::: walk
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Give ----> VERB ::::: give
# me ----> PRON ::::: I
# a ----> DET ::::: a
# second ----> NOUN ::::: second
# , ----> PUNCT ::::: ,
# Bond ----> PROPN ::::: Bond
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# - ----> PUNCT ::::: -
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# get ----> VERB ::::: get
# you ----> PRON ::::: you
# dried ----> VERB ::::: dry
# right ----> ADV ::::: right
# away ----> ADV ::::: away
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# - ----> PUNCT ::::: -
# Thanks ----> NOUN ::::: thank
# , ----> PUNCT ::::: ,
# Yor ----> PROPN ::::: Yor
# . ----> PROPN ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Father ----> PROPN ::::: Father
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Father ----> PROPN ::::: Father
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# Bond ----> PROPN ::::: Bond
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# award ----> VERB ::::: award
# you ----> PRON ::::: you
# both ----> PRON ::::: both
#
#
#  ----> SPACE :::::
#
#
# with ----> ADP ::::: with
# a ----> DET ::::: a
# Stella ----> PROPN ::::: Stella
# Star ----> PROPN ::::: Star
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# playing ----> VERB ::::: play
# pretend ----> VERB ::::: pretend
# with ----> ADP ::::: with
# Stella ----> PROPN ::::: Stella
# Stars ----> PROPN ::::: Stars
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# the ----> DET ::::: the
# " ----> PUNCT ::::: "
# You ----> PROPN ::::: You
# Worked ----> VERB ::::: work
# Super ----> PROPN ::::: Super
# Hard ----> PROPN ::::: Hard
#
#
#  ----> SPACE :::::
#
#
# While ----> SCONJ ::::: while
# Taking ----> VERB ::::: take
# A ----> PRON ::::: a
# Walk ----> PROPN ::::: Walk
# " ----> PUNCT ::::: "
# award ----> NOUN ::::: award
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Wow ----> INTJ ::::: wow
# ! ----> PUNCT ::::: !
# Loid ----> PROPN ::::: Loid
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# Bond ----> NOUN ::::: bond
# , ----> PUNCT ::::: ,
# congratulations ----> NOUN ::::: congratulation
# ! ----> PUNCT ::::: !
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# all ----> ADV ::::: all
# great ----> ADJ ::::: great
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# please ----> VERB ::::: please
#
#
#  ----> SPACE :::::
#
#
# earn ----> VERB ::::: earn
# yourself ----> PRON ::::: yourself
# a ----> DET ::::: a
# real ----> ADJ ::::: real
# Stella ----> PROPN ::::: Stella
# Star ----> PROPN ::::: Star
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# Oh ----> INTJ ::::: oh
# god ----> PROPN ::::: god
# ... ----> PUNCT ::::: ...
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# All ----> ADV ::::: all
# right ----> ADV ::::: right
# , ----> PUNCT ::::: ,
# time ----> NOUN ::::: time
# to ----> PART ::::: to
# prepare ----> VERB ::::: prepare
# dinner ----> NOUN ::::: dinner
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# help ----> VERB ::::: help
# . ----> PUNCT ::::: .
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
# I ----> PRON ::::: I
# want ----> VERB ::::: want
# to ----> PART ::::: to
# eat ----> VERB ::::: eat
# Father ----> PROPN ::::: Father
# 's ----> PART ::::: 's
# Hamburg ----> PROPN ::::: Hamburg
# steak ----> NOUN ::::: steak
# ! ----> PUNCT ::::: !

# %%
# Remember, we can request an explanation from spaCy of its tags: 
spacy.explain("DET")
# Out:
# 'determiner'

# %% [markdown]
# ### Okay, let's select something interesting
#  ...and maybe only collect the lemmas.
#
# Let's do this with a **function** call. We can easily switch the kind of word we want to output this way.
# Here we are starting to associate words wtih volumes...we're going to refine that by making a dataframe next.

# %%
def wordCollector(words, unit):
    wordList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append((token.lemma_, unit))
    uniqueLems = set(wordList)
    return uniqueLems

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myWords = wordCollector(spacyRead, name)
            print(myWords)
# Out:
# {('thick', '02x01_-_Follow_Mama_and_Papa'), ('extreme', '02x01_-_Follow_Mama_and_Papa'), ('capable', '02x01_-_Follow_Mama_and_Papa'), ('hungry', '02x01_-_Follow_Mama_and_Papa'), ('more', '02x01_-_Follow_Mama_and_Papa'), ('lone', '02x01_-_Follow_Mama_and_Papa'), ('important', '02x01_-_Follow_Mama_and_Papa'), ('discrete', '02x01_-_Follow_Mama_and_Papa'), ('certain', '02x01_-_Follow_Mama_and_Papa'), ('enough', '02x01_-_Follow_Mama_and_Papa'), ('impressive', '02x01_-_Follow_Mama_and_Papa'), ('odd', '02x01_-_Follow_Mama_and_Papa'), ('pitiful', '02x01_-_Follow_Mama_and_Papa'), ('exciting', '02x01_-_Follow_Mama_and_Papa'), ('perfect', '02x01_-_Follow_Mama_and_Papa'), ('ostanian', '02x01_-_Follow_Mama_and_Papa'), ('well', '02x01_-_Follow_Mama_and_Papa'), ('fun', '02x01_-_Follow_Mama_and_Papa'), ('countless', '02x01_-_Follow_Mama_and_Papa'), ('different', '02x01_-_Follow_Mama_and_Papa'), ('nice', '02x01_-_Follow_Mama_and_Papa'), ('mad', '02x01_-_Follow_Mama_and_Papa'), ('faint', '02x01_-_Follow_Mama_and_Papa'), ('like', '02x01_-_Follow_Mama_and_Papa'), ('hectic', '02x01_-_Follow_Mama_and_Papa'), ('high', '02x01_-_Follow_Mama_and_Papa'), ('unhappy', '02x01_-_Follow_Mama_and_Papa'), ('last', '02x01_-_Follow_Mama_and_Papa'), ('several', '02x01_-_Follow_Mama_and_Papa'), ('horrendous', '02x01_-_Follow_Mama_and_Papa'), ('pathetic', '02x01_-_Follow_Mama_and_Papa'), ('hopeless', '02x01_-_Follow_Mama_and_Papa'), ('extra', '02x01_-_Follow_Mama_and_Papa'), ('talented', '02x01_-_Follow_Mama_and_Papa'), ('bad', '02x01_-_Follow_Mama_and_Papa'), ('delicious', '02x01_-_Follow_Mama_and_Papa'), ('dangerous', '02x01_-_Follow_Mama_and_Papa'), ('cool', '02x01_-_Follow_Mama_and_Papa'), ('married', '02x01_-_Follow_Mama_and_Papa'), ('pufferfish', '02x01_-_Follow_Mama_and_Papa'), ('mean', '02x01_-_Follow_Mama_and_Papa'), ('psychic', '02x01_-_Follow_Mama_and_Papa'), ('fine', '02x01_-_Follow_Mama_and_Papa'), ('key', '02x01_-_Follow_Mama_and_Papa'), ('infamous', '02x01_-_Follow_Mama_and_Papa'), ('easy', '02x01_-_Follow_Mama_and_Papa'), ('tingly', '02x01_-_Follow_Mama_and_Papa'), ('bored', '02x01_-_Follow_Mama_and_Papa'), ('small', '02x01_-_Follow_Mama_and_Papa'), ('unwell', '02x01_-_Follow_Mama_and_Papa'), ('able', '02x01_-_Follow_Mama_and_Papa'), ('worried', '02x01_-_Follow_Mama_and_Papa'), ('wrong', '02x01_-_Follow_Mama_and_Papa'), ('little', '02x01_-_Follow_Mama_and_Papa'), ('armed', '02x01_-_Follow_Mama_and_Papa'), ('rare', '02x01_-_Follow_Mama_and_Papa'), ('sad', '02x01_-_Follow_Mama_and_Papa'), ('true', '02x01_-_Follow_Mama_and_Papa'), ('dry', '02x01_-_Follow_Mama_and_Papa'), ('much', '02x01_-_Follow_Mama_and_Papa'), ('original', '02x01_-_Follow_Mama_and_Papa'), ('sure', '02x01_-_Follow_Mama_and_Papa'), ('lethal', '02x01_-_Follow_Mama_and_Papa'), ('good', '02x01_-_Follow_Mama_and_Papa'), ('tired', '02x01_-_Follow_Mama_and_Papa'), ('personal', '02x01_-_Follow_Mama_and_Papa'), ('new', '02x01_-_Follow_Mama_and_Papa'), ('safe', '02x01_-_Follow_Mama_and_Papa'), ('great', '02x01_-_Follow_Mama_and_Papa'), ('many', '02x01_-_Follow_Mama_and_Papa'), ('young', '02x01_-_Follow_Mama_and_Papa'), ('fake', '02x01_-_Follow_Mama_and_Papa'), ('toxic', '02x01_-_Follow_Mama_and_Papa'), ('surprising', '02x01_-_Follow_Mama_and_Papa'), ('right', '02x01_-_Follow_Mama_and_Papa'), ('olive', '02x01_-_Follow_Mama_and_Papa'), ('careful', '02x01_-_Follow_Mama_and_Papa'), ('other', '02x01_-_Follow_Mama_and_Papa'), ('loose', '02x01_-_Follow_Mama_and_Papa'), ('obtrusive', '02x01_-_Follow_Mama_and_Papa'), ('fierce', '02x01_-_Follow_Mama_and_Papa'), ('boring', '02x01_-_Follow_Mama_and_Papa'), ('secret', '02x01_-_Follow_Mama_and_Papa'), ('worldwide', '02x01_-_Follow_Mama_and_Papa'), ('skilled', '02x01_-_Follow_Mama_and_Papa'), ('actual', '02x01_-_Follow_Mama_and_Papa'), ('sharp', '02x01_-_Follow_Mama_and_Papa'), ('sorry', '02x01_-_Follow_Mama_and_Papa'), ('single', '02x01_-_Follow_Mama_and_Papa'), ('own', '02x01_-_Follow_Mama_and_Papa'), ('normal', '02x01_-_Follow_Mama_and_Papa'), ('casual', ' ...
# {('nice', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('big', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('idle', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('ready', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('able', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('healthy', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('worried', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('warm', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('left', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('little', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('helpful', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('final', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('stray', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('lazy', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('insane', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('fancy', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('dry', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('much', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('famous', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('sure', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('possible', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('disheveled', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('good', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('cold', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('new', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('commendable', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('safe', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('sick', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('many', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('young', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('wonderful', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('dead', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('right', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('careful', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('other', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('beautiful', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('serious', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('second', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('late', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('yummy', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('skilled', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('okay', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('only', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('sorry', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('own', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('happy', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('hungry', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('unrefined', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('super', '02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s_Field_Research_Trip'), ('shallow',  ...
# {('necessary', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('more', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('hard', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('underground', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('delicious', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('pitiful', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('amazing', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('female', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('rid', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('usual', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('next', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('12th', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('well', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('nice', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('fun', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('big', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('sudden', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('sophisticated', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('third', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('public', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('past', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('mere', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('u-8', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('ridiculous', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('thorough', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('last', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('kind', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('stingy', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('awake', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('courteous', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('bad', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('lovely', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('dangerous', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('cool', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('suspicious', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('elegant', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('original', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('extremist', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('-', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('lovey', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('hefty', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('polar', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('aware', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('sick', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('worthwhile', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('relieved', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('ready', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('fellow', '02x03_-_Mission_and_Family-The_Elegant_Bondman-The_Heart_of_a_Child'), ('set', '02x03_-_Mi ...
# {('phantom', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('desperate', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('identical', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('urban', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('close', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('dirty', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('only', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('mysterious', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('sorry', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('own', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('normal', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('happy', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('same', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('gray', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('about', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('more', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('hard', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('lucky', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('special', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('certain', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('long', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('entire', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('former', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('amazing', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('soft', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('female', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('embarrassing', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('exciting', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('rude', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('limited', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('fierce', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('next', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('adamant', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('well', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('worth', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('mad', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('classical', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('academic', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('stupid', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('very', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('royal', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('ridiculous', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('high', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('last', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('simple', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('available', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('extra', '02x04_-_The_Pastry_of_Knowledge-The_Informant_s_Great_Romance_Plan_II'), ('talented ...
# {('scrubby', '02x05_-_Plan_to_Cross_the_Border'), ('original', '02x05_-_Plan_to_Cross_the_Border'), ('sure', '02x05_-_Plan_to_Cross_the_Border'), ('short', '02x05_-_Plan_to_Cross_the_Border'), ('excited', '02x05_-_Plan_to_Cross_the_Border'), ('first', '02x05_-_Plan_to_Cross_the_Border'), ('cold', '02x05_-_Plan_to_Cross_the_Border'), ('recent', '02x05_-_Plan_to_Cross_the_Border'), ('unnoticed', '02x05_-_Plan_to_Cross_the_Border'), ('aware', '02x05_-_Plan_to_Cross_the_Border'), ('luxurious', '02x05_-_Plan_to_Cross_the_Border'), ('free', '02x05_-_Plan_to_Cross_the_Border'), ('great', '02x05_-_Plan_to_Cross_the_Border'), ('outside', '02x05_-_Plan_to_Cross_the_Border'), ('numerous', '02x05_-_Plan_to_Cross_the_Border'), ('wonderful', '02x05_-_Plan_to_Cross_the_Border'), ('friendly', '02x05_-_Plan_to_Cross_the_Border'), ('indebted', '02x05_-_Plan_to_Cross_the_Border'), ('relaxing', '02x05_-_Plan_to_Cross_the_Border'), ('able', '02x05_-_Plan_to_Cross_the_Border'), ('concerned', '02x05_-_Plan_to_Cross_the_Border'), ('honorable', '02x05_-_Plan_to_Cross_the_Border'), ('wrong', '02x05_-_Plan_to_Cross_the_Border'), ('right', '02x05_-_Plan_to_Cross_the_Border'), ('careful', '02x05_-_Plan_to_Cross_the_Border'), ('sixth', '02x05_-_Plan_to_Cross_the_Border'), ('beautiful', '02x05_-_Plan_to_Cross_the_Border'), ('meticulous', '02x05_-_Plan_to_Cross_the_Border'), ('biannual', '02x05_-_Plan_to_Cross_the_Border'), ('proper', '02x05_-_Plan_to_Cross_the_Border'), ('urban', '02x05_-_Plan_to_Cross_the_Border'), ('sad', '02x05_-_Plan_to_Cross_the_Border'), ('true', '02x05_-_Plan_to_Cross_the_Border'), ('reassuring', '02x05_-_Plan_to_Cross_the_Border'), ('okay', '02x05_-_Plan_to_Cross_the_Border'), ('honest', '02x05_-_Plan_to_Cross_the_Border'), ('famous', '02x05_-_Plan_to_Cross_the_Border'), ('only', '02x05_-_Plan_to_Cross_the_Border'), ('possible', '02x05_-_Plan_to_Cross_the_Border'), ('good', '02x05_-_Plan_to_Cross_the_Border'), ('tired', '02x05_-_Plan_to_Cross_the_Border'), ('full', '02x05_-_Plan_to_Cross_the_Border'), ('own', '02x05_-_Plan_to_Cross_the_Border'), ('new', '02x05_-_Plan_to_Cross_the_Border'), ('old', '02x05_-_Plan_to_Cross_the_Border'), ('safe', '02x05_-_Plan_to_Cross_the_Border'), ('difficult', '02x05_-_Plan_to_Cross_the_Border'), ('real', '02x05_-_Plan_to_Cross_the_Border'), ('more', '02x05_-_Plan_to_Cross_the_Border'), ('hard', '02x05_-_Plan_to_Cross_the_Border'), ('internal', '02x05_-_Plan_to_Cross_the_Border'), ('many', '02x05_-_Plan_to_Cross_the_Border'), ('fearsome', '02x05_-_Plan_to_Cross_the_Border'), ('dependent', '02x05_-_Plan_to_Cross_the_Border'), ('long', '02x05_-_Plan_to_Cross_the_Border'), ('large', '02x05_-_Plan_to_Cross_the_Border'), ('amazing', '02x05_-_Plan_to_Cross_the_Border'), ('political', '02x05_-_Plan_to_Cross_the_Border'), ('correct', '02x05_-_Plan_to_Cross_the_Border'), ('other', '02x05_-_Plan_to_Cross_the_Border'), ('top', '02x05_-_Plan_to_Cross_the_Border'), ('fair', '02x05_-_Plan_to_Cross_the_Border'), ('serious', '02x05_-_Plan_to_Cross_the_Border'), ('vibrant', '02x05_-_Plan_to_Cross_the_Border'), ('next', '02x05_-_Plan_to_Cross_the_Border'), ('well', '02x05_-_Plan_to_Cross_the_Border'), ('different', '02x05_-_Plan_to_Cross_the_Border'), ('hidden', '02x05_-_Plan_to_Cross_the_Border'), ('actual', '02x05_-_Plan_to_Cross_the_Border'), ('picky', '02x05_-_Plan_to_Cross_the_Border'), ('frail', '02x05_-_Plan_to_Cross_the_Border'), ('sorry', '02x05_-_Plan_to_Cross_the_Border'), ('mega', '02x05_-_Plan_to_Cross_the_Border'), ('main', '02x05_-_Plan_to_Cross_the_Border'), ('same', '02x05_-_Plan_to_Cross_the_Border'), ('clear', '02x05_-_Plan_to_Cross_the_Border'), ('available', '02x05_-_Plan_to_Cross_the_Border'), ('about', '02x05_-_Plan_to_Cross_the_Border'), ('important', '02x05_-_Plan_to_Cross_the_Border'), ('bad', '02x05_-_Plan_to_Cross_the_Border'), ('certain', '02x05_-_Plan_to_Cross_the_Border'), ('delicious', '02x05_-_Plan_to_Cross_the_Border'), ('female', '02x05_-_Plan_to_Cross_the_Border'), ('suspicious', '0 ...
# {('damn', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('idiot', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('able', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('black', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('wrong', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('overwhelming', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('private', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('second', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('little', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('sad', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('skilled', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('much', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('good', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('lonesome', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('new', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('wooden', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('fitting', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('low', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('hungry', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('more', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('many', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('fearsome', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('lucky', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('local', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('entire', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('extravagant', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('right', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('correct', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('perfect', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('other', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('blind', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('jealous', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('blonde', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('cute', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('late', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('close', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('public', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('entertaining', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('sorry', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('single', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('psychotic', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('complete', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('normal', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('same', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('particular', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('about', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('important', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('constant', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('nervous', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('enough', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('delicious', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('female', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('exciting', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('boorish', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('haired', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('easy', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('fun', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('big', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('different', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('mad', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('squid', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('third', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('mental', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('strong', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('fast', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('optimal', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('last', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('cheerful', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('bad', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('crucial', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('least', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('few', '02x06_-_The_Fearsome_Luxury_Cruise_Ship'), ('unstable', '02x06_-_The_Fearsome_Luxury_Crui ...
# {('sorry', '02x07_-_Who_Is_This_Mission_For_'), ('normal', '02x07_-_Who_Is_This_Mission_For_'), ('main', '02x07_-_Who_Is_This_Mission_For_'), ('clear', '02x07_-_Who_Is_This_Mission_For_'), ('fatal', '02x07_-_Who_Is_This_Mission_For_'), ('important', '02x07_-_Who_Is_This_Mission_For_'), ('cheerful', '02x07_-_Who_Is_This_Mission_For_'), ('overconfident', '02x07_-_Who_Is_This_Mission_For_'), ('satisfied', '02x07_-_Who_Is_This_Mission_For_'), ('scary', '02x07_-_Who_Is_This_Mission_For_'), ('enough', '02x07_-_Who_Is_This_Mission_For_'), ('exciting', '02x07_-_Who_Is_This_Mission_For_'), ('female', '02x07_-_Who_Is_This_Mission_For_'), ('pet', '02x07_-_Who_Is_This_Mission_For_'), ('angry', '02x07_-_Who_Is_This_Mission_For_'), ('loud', '02x07_-_Who_Is_This_Mission_For_'), ('fun', '02x07_-_Who_Is_This_Mission_For_'), ('nice', '02x07_-_Who_Is_This_Mission_For_'), ('big', '02x07_-_Who_Is_This_Mission_For_'), ('different', '02x07_-_Who_Is_This_Mission_For_'), ('rebellious', '02x07_-_Who_Is_This_Mission_For_'), ('third', '02x07_-_Who_Is_This_Mission_For_'), ('scared', '02x07_-_Who_Is_This_Mission_For_'), ('calm', '02x07_-_Who_Is_This_Mission_For_'), ('likely', '02x07_-_Who_Is_This_Mission_For_'), ('lonely', '02x07_-_Who_Is_This_Mission_For_'), ('last', '02x07_-_Who_Is_This_Mission_For_'), ('busy', '02x07_-_Who_Is_This_Mission_For_'), ('afraid', '02x07_-_Who_Is_This_Mission_For_'), ('pathetic', '02x07_-_Who_Is_This_Mission_For_'), ('hopeless', '02x07_-_Who_Is_This_Mission_For_'), ('fit', '02x07_-_Who_Is_This_Mission_For_'), ('upset', '02x07_-_Who_Is_This_Mission_For_'), ('least', '02x07_-_Who_Is_This_Mission_For_'), ('yor', '02x07_-_Who_Is_This_Mission_For_'), ('open', '02x07_-_Who_Is_This_Mission_For_'), ('cool', '02x07_-_Who_Is_This_Mission_For_'), ('suspicious', '02x07_-_Who_Is_This_Mission_For_'), ('huge', '02x07_-_Who_Is_This_Mission_For_'), ('quiet', '02x07_-_Who_Is_This_Mission_For_'), ('such', '02x07_-_Who_Is_This_Mission_For_'), ('evil', '02x07_-_Who_Is_This_Mission_For_'), ('original', '02x07_-_Who_Is_This_Mission_For_'), ('sure', '02x07_-_Who_Is_This_Mission_For_'), ('troubling', '02x07_-_Who_Is_This_Mission_For_'), ('unidentified', '02x07_-_Who_Is_This_Mission_For_'), ('dummy', '02x07_-_Who_Is_This_Mission_For_'), ('flashy', '02x07_-_Who_Is_This_Mission_For_'), ('crazy', '02x07_-_Who_Is_This_Mission_For_'), ('useless', '02x07_-_Who_Is_This_Mission_For_'), ('young', '02x07_-_Who_Is_This_Mission_For_'), ('ready', '02x07_-_Who_Is_This_Mission_For_'), ('able', '02x07_-_Who_Is_This_Mission_For_'), ('black', '02x07_-_Who_Is_This_Mission_For_'), ('wrong', '02x07_-_Who_Is_This_Mission_For_'), ('careful', '02x07_-_Who_Is_This_Mission_For_'), ('heroic', '02x07_-_Who_Is_This_Mission_For_'), ('glad', '02x07_-_Who_Is_This_Mission_For_'), ('little', '02x07_-_Who_Is_This_Mission_For_'), ('second', '02x07_-_Who_Is_This_Mission_For_'), ('invisible', '02x07_-_Who_Is_This_Mission_For_'), ('intermediate', '02x07_-_Who_Is_This_Mission_For_'), ('pro', '02x07_-_Who_Is_This_Mission_For_'), ('skilled', '02x07_-_Who_Is_This_Mission_For_'), ('headed', '02x07_-_Who_Is_This_Mission_For_'), ('okay', '02x07_-_Who_Is_This_Mission_For_'), ('much', '02x07_-_Who_Is_This_Mission_For_'), ('possible', '02x07_-_Who_Is_This_Mission_For_'), ('obedient', '02x07_-_Who_Is_This_Mission_For_'), ('good', '02x07_-_Who_Is_This_Mission_For_'), ('first', '02x07_-_Who_Is_This_Mission_For_'), ('happy', '02x07_-_Who_Is_This_Mission_For_'), ('uncool', '02x07_-_Who_Is_This_Mission_For_'), ('new', '02x07_-_Who_Is_This_Mission_For_'), ('old', '02x07_-_Who_Is_This_Mission_For_'), ('successful', '02x07_-_Who_Is_This_Mission_For_'), ('flawless', '02x07_-_Who_Is_This_Mission_For_'), ('difficult', '02x07_-_Who_Is_This_Mission_For_'), ('unable', '02x07_-_Who_Is_This_Mission_For_'), ('more', '02x07_-_Who_Is_This_Mission_For_'), ('hard', '02x07_-_Who_Is_This_Mission_For_'), ('many', '02x07_-_Who_Is_This_Mission_For_'), ('unknown', '02x07_-_Who_Is_This_Mission_For_'), ('underground', '02x07_-_Wh ...
# {('rid', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('haired', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('foreign', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('big', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('different', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('mad', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('sudden', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('grueling', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('scared', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('strong', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('likely', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('natural', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('last', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('kind', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('busy', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('green', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('bad', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('heavy', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('proud', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('suspicious', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('fashioned', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('quiet', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('insane', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('such', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('unnecessary', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('fine', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('popular', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('original', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('herbal', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('loud', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('easy', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('unfamiliar', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('carefree', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('climactic', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('memorable', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('unwarranted', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('sick', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('reckless', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('bored', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('idiot', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('able', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('pretty', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('black', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('healthy', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('horrible', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('unexpected', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('little', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('skilled', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('dry', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('okay', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('inflatable', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('disgusting', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('much', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('famous', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('sure', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('possible', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('good', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('tired', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('first', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('cold', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('happy', '02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea'), ('old', '02x08_-_The_Symphon ...
# {('convenient', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('happy', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('uncool', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('new', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('low', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('old', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('safe', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('crazy', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('thorough', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('same', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('great', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('risky', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('last', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('simple', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('more', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('many', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('young', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('busy', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('eastern', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('available', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('about', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('able', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('common', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('warm', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('scary', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('entire', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('straightforward', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('asleep', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('impossible', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('enough', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('amazing', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('alive', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('bad', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('deadly', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('right', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('careful', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('peaceful', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('beautiful', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('exciting', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('other', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('darn', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('glad', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('cool', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('fullest', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('suspicious', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('little', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('second', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('late', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('such', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('western', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('secret', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('crowded', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('close', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('original', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('worth', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('sure', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('sentimental', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('easy', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('dirty', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('big', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('hey', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('mad', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('possible', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('strange', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('carefree', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('good', '02x09_-_The_Hand_That_Connects_to_the_Future'), ('sorry', '02x09_-_The_Hand_That_Connects_to_the_Futur ...
# {('worthy', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('third', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('ideal', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('simple', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('peaceful', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('lovely', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('little', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('cool', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('dangerous', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('careless', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('la', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('complicated', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('thrilling', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('original', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('excited', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('first', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('awful', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('unfair', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('sleepy', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('tra', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('numerous', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('ready', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('wrong', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('right', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('remarkable', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('beautiful', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('nice', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('glad', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('true', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('skilled', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('ordinary', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('okay', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('much', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('possible', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('good', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('tired', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('big', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('swollen', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('happy', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('new', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('old', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('threatening', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('more', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('hard', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('many', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('fake', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('unknown', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('lucky', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('long', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('bold', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_About_Vacation'), ('large', '02x10_-_Enjoy_the_Resort_to_the_Fullest-Bragging_Ab ...
# {('willing', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('lovely', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('major', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('hot', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('rounded', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('curious', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('such', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('nice', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('easy', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('big', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('-first', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('useless', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('strong', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('small', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('last', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('awake', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('busy', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('nauseous', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('tough', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('worried', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('broad', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('ill', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('professional', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('smiley', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('few', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('sexy', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('little', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('ordinary', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('fine', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('original', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('famous', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('sure', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('first', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('suited', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('aware', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('useful', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('safe', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('future', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('crazy', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('great', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('womanly', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('many', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('weak', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('able', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('wrong', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('right', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('wise', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('other', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('rich', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('potential', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('acute', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('glad', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('worthless', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('drunk', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('formal', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('helpful', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('urgent', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('experienced', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('valuable', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('close', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('true', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('yummy', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('skilled', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('okay', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ('sorry', '02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life'), ...
# {('intelligent', '02x12_-_Part_of_the_Family'), ('different', '02x12_-_Part_of_the_Family'), ('worth', '02x12_-_Part_of_the_Family'), ('sudden', '02x12_-_Part_of_the_Family'), ('serial', '02x12_-_Part_of_the_Family'), ('scared', '02x12_-_Part_of_the_Family'), ('preposterous', '02x12_-_Part_of_the_Family'), ('normal', '02x12_-_Part_of_the_Family'), ('high', '02x12_-_Part_of_the_Family'), ('simple', '02x12_-_Part_of_the_Family'), ('busy', '02x12_-_Part_of_the_Family'), ('extra', '02x12_-_Part_of_the_Family'), ('bad', '02x12_-_Part_of_the_Family'), ('alive', '02x12_-_Part_of_the_Family'), ('dangerous', '02x12_-_Part_of_the_Family'), ('thin', '02x12_-_Part_of_the_Family'), ('multiple', '02x12_-_Part_of_the_Family'), ('wet', '02x12_-_Part_of_the_Family'), ('hot', '02x12_-_Part_of_the_Family'), ('military', '02x12_-_Part_of_the_Family'), ('psychic', '02x12_-_Part_of_the_Family'), ('nice', '02x12_-_Part_of_the_Family'), ('reckless', '02x12_-_Part_of_the_Family'), ('useless', '02x12_-_Part_of_the_Family'), ('enjoyable', '02x12_-_Part_of_the_Family'), ('tough', '02x12_-_Part_of_the_Family'), ('able', '02x12_-_Part_of_the_Family'), ('alone', '02x12_-_Part_of_the_Family'), ('wrong', '02x12_-_Part_of_the_Family'), ('innocent', '02x12_-_Part_of_the_Family'), ('restless', '02x12_-_Part_of_the_Family'), ('little', '02x12_-_Part_of_the_Family'), ('wilted', '02x12_-_Part_of_the_Family'), ('huge', '02x12_-_Part_of_the_Family'), ('addictive', '02x12_-_Part_of_the_Family'), ('sad', '02x12_-_Part_of_the_Family'), ('popular', '02x12_-_Part_of_the_Family'), ('original', '02x12_-_Part_of_the_Family'), ('sure', '02x12_-_Part_of_the_Family'), ('critical', '02x12_-_Part_of_the_Family'), ('key', '02x12_-_Part_of_the_Family'), ('tired', '02x12_-_Part_of_the_Family'), ('first', '02x12_-_Part_of_the_Family'), ('clean', '02x12_-_Part_of_the_Family'), ('safe', '02x12_-_Part_of_the_Family'), ('low', '02x12_-_Part_of_the_Family'), ('sick', '02x12_-_Part_of_the_Family'), ('weird', '02x12_-_Part_of_the_Family'), ('unfair', '02x12_-_Part_of_the_Family'), ('difficult', '02x12_-_Part_of_the_Family'), ('great', '02x12_-_Part_of_the_Family'), ('skinny', '02x12_-_Part_of_the_Family'), ('outside', '02x12_-_Part_of_the_Family'), ('many', '02x12_-_Part_of_the_Family'), ('fake', '02x12_-_Part_of_the_Family'), ('irrational', '02x12_-_Part_of_the_Family'), ('fluffy', '02x12_-_Part_of_the_Family'), ('right', '02x12_-_Part_of_the_Family'), ('other', '02x12_-_Part_of_the_Family'), ('serious', '02x12_-_Part_of_the_Family'), ('plastic', '02x12_-_Part_of_the_Family'), ('glad', '02x12_-_Part_of_the_Family'), ('inside', '02x12_-_Part_of_the_Family'), ('true', '02x12_-_Part_of_the_Family'), ('skilled', '02x12_-_Part_of_the_Family'), ('gentle', '02x12_-_Part_of_the_Family'), ('much', '02x12_-_Part_of_the_Family'), ('only', '02x12_-_Part_of_the_Family'), ('strange', '02x12_-_Part_of_the_Family'), ('sorry', '02x12_-_Part_of_the_Family'), ('good', '02x12_-_Part_of_the_Family'), ('personal', '02x12_-_Part_of_the_Family'), ('own', '02x12_-_Part_of_the_Family'), ('real', '02x12_-_Part_of_the_Family'), ('hungry', '02x12_-_Part_of_the_Family'), ('hard', '02x12_-_Part_of_the_Family'), ('shriveled', '02x12_-_Part_of_the_Family'), ('discrete', '02x12_-_Part_of_the_Family'), ('super', '02x12_-_Part_of_the_Family'), ('suspect', '02x12_-_Part_of_the_Family'), ('enough', '02x12_-_Part_of_the_Family'), ('impressive', '02x12_-_Part_of_the_Family'), ('amazing', '02x12_-_Part_of_the_Family'), ('fierce', '02x12_-_Part_of_the_Family'), ('ostanian', '02x12_-_Part_of_the_Family'), ('jealous', '02x12_-_Part_of_the_Family'), ('cute', '02x12_-_Part_of_the_Family')}

# %% [markdown]
# ### Let's try dataframes to store these relations of word-form to unit
# Dataframes, supporteed by the pandas library in Python, facilitate handling data in spreadsheet / CSV / TSV format.
# We want to output some data to a TSV (tab-separated values file) so we can send it to network visualization software.
#
# We'll need to open a terminal and  **pip install pandas** (or python3.12 -m pip install pandas) to get dataframes working.

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            print(myDataFrame)
# Out:
#           word nodeType                          unit
# 0    worldwide      ADJ  02x01_-_Follow_Mama_and_Papa
# 1     discrete      ADJ  02x01_-_Follow_Mama_and_Papa
# 2       fierce      ADJ  02x01_-_Follow_Mama_and_Papa
# 3          key      ADJ  02x01_-_Follow_Mama_and_Papa
# 4     ostanian      ADJ  02x01_-_Follow_Mama_and_Papa
# ..         ...      ...                           ...
# 143     hectic      ADJ  02x01_-_Follow_Mama_and_Papa
# 144  delicious      ADJ  02x01_-_Follow_Mama_and_Papa
# 145       well      ADJ  02x01_-_Follow_Mama_and_Papa
# 146      young      ADJ  02x01_-_Follow_Mama_and_Papa
# 147      young      ADJ  02x01_-_Follow_Mama_and_Papa
#
# [148 rows x 3 columns]
#         word nodeType                                               unit
# 0    special      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# 1      happy      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# 2      final      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# 3       busy      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# 4      sorry      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# ..       ...      ...                                                ...
# 115     able      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# 116  elegant      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# 117      fun      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# 118   little      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
# 119  elegant      ADJ  02x02_-_Bond_s_Strategy_to_Stay_Alive-Damian_s...
#
# [120 rows x 3 columns]
#          word nodeType                                               unit
# 0    original      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# 1       hefty      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# 2        good      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# 3      lovely      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# 4        good      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# ..        ...      ...                                                ...
# 119     awake      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# 120      sure      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# 121      late      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# 122      many      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
# 123     great      ADJ  02x03_-_Mission_and_Family-The_Elegant_Bondman...
#
# [124 rows x 3 columns]
#            word nodeType                                               unit
# 0    mysterious      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# 1     exquisite      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# 2          many      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# 3         smart      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# 4      original      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# ..          ...      ...                                                ...
# 155        glad      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# 156        safe      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# 157   sarcastic      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# 158     special      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
# 159         new      ADJ  02x04_-_The_Pastry_of_Knowledge-The_Informant_...
#
# [160 rows x 3 columns]
#            word nodeType                              unit
# 0     beautiful      ADJ  02x05_-_Plan_to_Cross_the_Border
# 1        proper      ADJ  02x05_-_Plan_to_Cross_the_Border
# 2    meticulous      ADJ  02x05_-_Plan_to_Cross_the_Border
# 3     wonderful      ADJ  02x05_-_Plan_to_Cross_the_Border
# 4       vibrant      ADJ  02x05_-_Plan_to_Cross_the_Border
# ..          ...      ...                               ...
# 171   delicious      ADJ  02x05_-_Plan_to_Cross_the_Border
# 172       clear      ADJ  02x05_-_Plan_to_Cross_the_Border
# 173        same      ADJ  02x05_-_Plan_to_Cross_the_Border
# 174       sorry      ADJ  02x05_-_Plan_to_Cross_the_Border
# 175    fearsome      ADJ  02x05_-_Plan_to_Cross_the_Border
#
# [176 rows x 3 columns]
#              word nodeType                                     unit
# 0           lucky      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 1          unfair      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 2    entertaining      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 3          female      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 4            same      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# ..            ...      ...                                      ...
# 136          good      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 137       perfect      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 138         other      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 139          last      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
# 140        strong      ADJ  02x06_-_The_Fearsome_Luxury_Cruise_Ship
#
# [141 rows x 3 columns]
#              word nodeType                              unit
# 0        original      ADJ  02x07_-_Who_Is_This_Mission_For_
# 1    intermediate      ADJ  02x07_-_Who_Is_This_Mission_For_
# 2            hard      ADJ  02x07_-_Who_Is_This_Mission_For_
# 3           close      ADJ  02x07_-_Who_Is_This_Mission_For_
# 4         skilled      ADJ  02x07_-_Who_Is_This_Mission_For_
# ..            ...      ...                               ...
# 129          main      ADJ  02x07_-_Who_Is_This_Mission_For_
# 130          hard      ADJ  02x07_-_Who_Is_This_Mission_For_
# 131         ready      ADJ  02x07_-_Who_Is_This_Mission_For_
# 132  unidentified      ADJ  02x07_-_Who_Is_This_Mission_For_
# 133         clear      ADJ  02x07_-_Who_Is_This_Mission_For_
#
# [134 rows x 3 columns]
#            word nodeType                                               unit
# 0      original      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 1      dazzling      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 2     memorable      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 3          last      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 4    inflatable      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# ..          ...      ...                                                ...
# 121        glad      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 122        okay      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 123      famous      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 124  disgusting      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
# 125     similar      ADJ  02x08_-_The_Symphony_Upon_the_Ship-Sis_s_Herb_Tea
#
# [126 rows x 3 columns]
#         word nodeType                                          unit
# 0      other      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# 1      grand      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# 2      grand      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# 3     entire      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# 4       same      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# ..       ...      ...                                           ...
# 107     sure      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# 108     late      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# 109   asleep      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# 110    sorry      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
# 111  fullest      ADJ  02x09_-_The_Hand_That_Connects_to_the_Future
#
# [112 rows x 3 columns]
#             word nodeType                                               unit
# 0       original      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# 1           glad      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# 2      unnerving      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# 3        excited      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# 4         simple      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# ..           ...      ...                                                ...
# 114        right      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# 115         good      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# 116         true      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# 117     possible      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
# 118  complicated      ADJ  02x10_-_Enjoy_the_Resort_to_the_Fullest-Braggi...
#
# [119 rows x 3 columns]
#            word nodeType                                            unit
# 0      original      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 1         right      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 2         great      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 3          good      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 4         sorry      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# ..          ...      ...                                             ...
# 162        sure      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 163  particular      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 164         own      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 165        good      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
# 166        good      ADJ  02x11_-_Berlint_in_Love-Nightfall_s_Daily_Life
#
# [167 rows x 3 columns]
#          word nodeType                        unit
# 0    discrete      ADJ  02x12_-_Part_of_the_Family
# 1      fierce      ADJ  02x12_-_Part_of_the_Family
# 2         key      ADJ  02x12_-_Part_of_the_Family
# 3    ostanian      ADJ  02x12_-_Part_of_the_Family
# 4     skilled      ADJ  02x12_-_Part_of_the_Family
# ..        ...      ...                         ...
# 127       wet      ADJ  02x12_-_Part_of_the_Family
# 128    fluffy      ADJ  02x12_-_Part_of_the_Family
# 129     great      ADJ  02x12_-_Part_of_the_Family
# 130     great      ADJ  02x12_-_Part_of_the_Family
# 131      real      ADJ  02x12_-_Part_of_the_Family
#
# [132 rows x 3 columns]

# %% [markdown]
# ## Write the dataframes to an output TSV file
# TSV means **tab-separated-values**. We'll use the tab character as a separator.
# The other popular alternative is the CSV: **comma-separated-values**, which uses the comma as a separator.
# You can use either one for our network data.
#
# I'm going to output some "node attributes" for tne network. In a network visualization, we'll want to be able to quickly distinguish the word nodes from the unit nodes (possibly by shape), and providing a qualifier or "node attribute" in the dataframe will be helpful.
# We can add other kinds of node attributes perhaps as numerical ranges (see below).

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)
# print(fullDataFrame)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a dataframe as a TSV file.')
# Go check your filestash for the file.
# Out:
# I just saved a dataframe as a TSV file.

# %% [markdown]
# ### Something to try...
# * Try developing this to return synsets from WordNet.
# * Add an Ambiguity metric to count the number of synsets it belongs to.
# * Output this as a second "node attribute" qualifier to the Part of Speech. We could use that to color-code the words by ambiguity...

# %%
# This time, with Wordnet data!
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    synsetCounts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            synsets = len(wn.synsets(token.lemma_))
            # We should be able to look up and count those synsets right here!          
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            synsetCounts.append(synsets)
            unitList.append(unit)
                          
    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'synsetCount': synsetCounts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData-2.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a NEW dataframe as a NEW TSV file.')
# Go check your filestash for the file.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 33
#      29
#      30 # We need to consolidate all the dataframes into one file. Collect all dataframes here!
#      31 allDataFrames = []
#      32
# ---> 33 for file in os.listdir(collPath):
#      34     if file.endswith(".txt"):
#      35         filepath = f"{collPath}/{file}"
#      36         name, extension = os.path.splitext(file)
#
# NameError: name 'os' is not defined

# %% [markdown]
# ## What will we do with this fancy TSV?
#
# We can analyze it as a **network** of data using network analysis. You could try importing your TSV into kumu.io, but we're going to introduce Cytoscape, which is a very powerful, artful method with lots of visualization options.
#
# To view the data we extracted in this notebook as an SVG export from Cytoscape, see <https://raw.githubusercontent.com/newtfire/textAnalysis-Hub/refs/heads/main/Class-Examples/Python/readFileCollections-examples/network-analysis-via-python/networkData-2.svg>

# %% [markdown]
# ## Your Turn!
# Adapt this notebook to explore one or more of your project files and prepare some network data of your own.
#
# * Output a CSV or TSV of data from your project for import into our network visualization software.
# * [Install Cytoscape](https://cytoscape.org/) on your computer and check to make sure it is working.
#      * Cytoscape now comes bundled with its own Java, so you should be good to go for running it (much like oXygen). If you have trouble, work through the [Troubleshooting](https://cytoscape.org/troubleshooting.html) guide first. Bring questions to class or via Canvas!
#      * After you install Cytoscape, see if you can also install the yFiles Layout Algorithms. Open Cytoscape, go to **Layout → Install yFiles**, which directs you to an App store to download it and apply it to Cytoscape.

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".xml"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'spyData.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)
# print(fullDataFrame)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a dataframe as a TSV file.')
# Go check your filestash for the file.
